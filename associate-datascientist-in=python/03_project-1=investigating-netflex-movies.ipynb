# %%
**Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.

Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.

You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!

You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!

## The data
### **netflix_data.csv**
| Column | Description |
|--------|-------------|
| `show_id` | The ID of the show |
| `type` | Type of show |
| `title` | Title of the show |
| `director` | Director of the show |
| `cast` | Cast of the show |
| `country` | Country of origin |
| `date_added` | Date added to Netflix |
| `release_year` | Year of Netflix release |
| `duration` | Duration of the show in minutes |
| `description` | Description of the show |
| `genre` | Show genre |

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Import pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# Filter the data for movies released in the 1990s
movies_1990s = netflix_df[(netflix_df['type'] == 'Movie') & 
                          (netflix_df['release_year'] >= 1990) & 
                          (netflix_df['release_year'] <= 1999)]

# Find the most frequent movie duration in the 1990s
duration_counts = movies_1990s['duration'].value_counts()
most_frequent_duration = duration_counts.idxmax()

# Visualize the distribution of durations for movies released in the 1990s
plt.figure(figsize=(10, 6))
plt.hist(movies_1990s['duration'], bins=30, edgecolor='k')
plt.title('Distribution of Movie Durations in the 1990s')
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')
plt.show()

# Save the most frequent duration as an integer
duration = int(most_frequent_duration)

# Count the number of short action movies from the 1990s
short_action_movies_1990s = movies_1990s[(movies_1990s['genre'] == 'Action') & 
                                         (movies_1990s['duration'] < 90)]
short_movie_count = len(short_action_movies_1990s)

# Print the results
print(f"The most frequent movie duration in the 1990s is: {duration} minutes")
print(f"The number of short action movies in the 1990s is: {short_movie_count}")

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset netflix_data.csv, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | show_id | The ID of the show |
# | type | Type of show |
# | title | Title of the show |
# | director | Director of the show |
# | cast | Cast of the show |
# | country | Country of origin |
# | date_added | Date added to Netflix |
# | release_year | Year of Netflix release |
# | duration | Duration of the show in minutes |
# | description | Description of the show |
# | genre | Show genre |
#
# # Importing pandas and matplotlib
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Read in the Netflix CSV as a DataFrame
# netflix_df = pd.read_csv("netflix_data.csv")
#
# Perform exploratory data analysis on the netflix_data.csv data to understand more about movies from the 1990s decade.
#
# What was the most frequent movie duration in the 1990s? Save an approximate answer as an integer called duration.
#
# A movie is considered short if it is less than 90 minutes. Count the number of short action movies released in the 1990s and save this integer as short_movie_count.
#
#
# How to approach the project
# 1. Filter the data for movies released in the 1990s
#
# 2. Find the most frequent movie duration
#
# 3. Count the number of short action movies from the 1990s
#
# Filter the data for movies released in the 1990s
# You'll want to subset the DataFrame to keep only the movies and then filter the years so that you are working with rows where the release year is between 1990 and 1999.
#
# Find the most frequent movie duration
# Visualize the data to view the distributions of durations for movies released in the 1990s.
#
# Count the number of short action movies from the 1990s
# First, subset the data again to keep only movies with the correct genre. Then, iterate through the data and count the number of movies depending on the condition pf a duration that is less than 90.
# ChatGPT
# Let's break down the process into the required steps to perform the exploratory data analysis on the Netflix data and answer the questions. Here's the step-by-step approach:
#
# Filter the data for movies released in the 1990s:
#
# Subset the DataFrame to keep only the movies.
# Filter the rows where the release year is between 1990 and 1999.
# Find the most frequent movie duration in the 1990s:
#
# Visualize the distribution of durations for movies released in the 1990s.
# Identify the most frequent duration.
# Count the number of short action movies from the 1990s:
#
# Subset the data to keep only movies with the genre "Action".
# Count the number of movies with a duration less than 90 minutes.
# Here's the Python code to achieve these tasks:
#
# python
# Copy code
# # Import pandas and matplotlib
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Read in the Netflix CSV as a DataFrame
# netflix_df = pd.read_csv("netflix_data.csv")
#
# # Filter the data for movies released in the 1990s
# movies_1990s = netflix_df[(netflix_df['type'] == 'Movie') &
#                           (netflix_df['release_year'] >= 1990) &
#                           (netflix_df['release_year'] <= 1999)]
#
# # Find the most frequent movie duration in the 1990s
# duration_counts = movies_1990s['duration'].value_counts()
# most_frequent_duration = duration_counts.idxmax()
#
# # Visualize the distribution of durations for movies released in the 1990s
# plt.figure(figsize=(10, 6))
# plt.hist(movies_1990s['duration'], bins=30, edgecolor='k')
# plt.title('Distribution of Movie Durations in the 1990s')
# plt.xlabel('Duration (minutes)')
# plt.ylabel('Frequency')
# plt.show()
#
# # Save the most frequent duration as an integer
# duration = int(most_frequent_duration)
#
# # Count the number of short action movies from the 1990s
# short_action_movies_1990s = movies_1990s[(movies_1990s['genre'] == 'Action') &
#                                          (movies_1990s['duration'] < 90)]
# short_movie_count = len(short_action_movies_1990s)
#
# # Print the results
# print(f"The most frequent movie duration in the 1990s is: {duration} minutes")
# print(f"The number of short action movies in the 1990s is: {short_movie_count}")
# Let's break down the code:
#
# Reading the Data:
#
# python
# Copy code
# netflix_df = pd.read_csv("netflix_data.csv")
# Filtering the Data for Movies Released in the 1990s:
#
# python
# Copy code
# movies_1990s = netflix_df[(netflix_df['type'] == 'Movie') &
#                           (netflix_df['release_year'] >= 1990) &
#                           (netflix_df['release_year'] <= 1999)]
# Finding the Most Frequent Movie Duration in the 1990s:
#
# python
# Copy code
# duration_counts = movies_1990s['duration'].value_counts()
# most_frequent_duration = duration_counts.idxmax()
# Visualizing the Distribution of Durations for Movies Released in the 1990s:
#
# python
# Copy code
# plt.figure(figsize=(10, 6))
# plt.hist(movies_1990s['duration'], bins=30, edgecolor='k')
# plt.title('Distribution of Movie Durations in the 1990s')
# plt.xlabel('Duration (minutes)')
# plt.ylabel('Frequency')
# plt.show()
# Saving the Most Frequent Duration as an Integer:
#
# python
# Copy code
# duration = int(most_frequent_duration)
# Counting the Number of Short Action Movies from the 1990s:
#
# python
# Copy code
# short_action_movies_1990s = movies_1990s[(movies_1990s['genre'] == 'Action') &
#                                          (movies_1990s['duration'] < 90)]
# short_movie_count = len(short_action_movies_1990s)
# Printing the Results:
#
# python
# Copy code
# print(f"The most frequent movie duration in the 1990s is: {duration} minutes")
# print(f"The number of short action movies in the 1990s is: {short_movie_count}")
# This code will provide you with the most frequent movie duration in the 1990s and the count of short action movies from that decade.
