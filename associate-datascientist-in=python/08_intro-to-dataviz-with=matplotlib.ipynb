# %%
# Import the matplotlib.pyplot submodule and name it plt
import matplotlib.pyplot as plt

# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Call the show function to show the result
plt.show()
# Nicely done! This script provides the basis for everything we'll do in this course.

# %% [markdown]
# '''Using the matplotlib.pyplot interface
# There are many ways to use Matplotlib. In this course, we will focus on the pyplot interface, which provides the most flexibility in creating and customizing data visualizations.
#
# Initially, we will use the pyplot interface to create two kinds of objects: Figure objects and Axes objects.
#
# This course introduces a lot of new concepts, so if you ever need a quick refresher, download the Matplotlib Cheat Sheet and keep it handy!
#
# Instructions
# 100 XP
# Import the matplotlib.pyplot API, using the conventional name plt.
# Create Figure and Axes objects using the plt.subplots function.
# Show the results, an empty set of axes, using the plt.show function'''
#
#
# # Import the matplotlib.pyplot submodule and name it plt
# import ____ as ____
#
# # Create a Figure and an Axes with plt.subplots
# fig, ax = ____
#
# # Call the show function to show the result
# ____
# ChatGPT
# Here's the solution to import the matplotlib.pyplot submodule, create Figure and Axes objects, and show the result using plt.show:
#
# python
# Copy code
# # Import the matplotlib.pyplot submodule and name it plt
# import matplotlib.pyplot as plt
#
# # Create a Figure and an Axes with plt.subplots
# fig, ax = plt.subplots()
#
# # Call the show function to show the result
# plt.show()

# %%
# Import the matplotlib.pyplot submodule and name it plt
import matplotlib.pyplot as plt

# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots()

# Plot MLY-PRCP-NORMAL from seattle_weather against the MONTH
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], label="Seattle")

# Plot MLY-PRCP-NORMAL from austin_weather against MONTH
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], label="Austin")

# Add a legend to distinguish between the two lines
ax.legend()

# Call the show function
plt.show()

# %% [markdown]
# '''Adding data to an Axes object
# Adding data to a figure is done by calling methods of the Axes object. In this exercise, we will use the plot method to add data about rainfall in two American cities: Seattle, WA and Austin, TX.
#
# The data are stored in two pandas DataFrame objects that are already loaded into memory: seattle_weather stores information about the weather in Seattle, and austin_weather stores information about the weather in Austin. Each of the DataFrames has a "MONTH" column that stores the three-letter name of the months. Each also has a column named "MLY-PRCP-NORMAL" that stores the average rainfall in each month during a ten-year period.
#
# In this exercise, you will create a visualization that will allow you to compare the rainfall in these two cities.
#
# Instructions
# 100 XP
# Import the matplotlib.pyplot submodule as plt.
# Create a Figure and an Axes object by calling plt.subplots.
# Add data from the seattle_weather DataFrame by calling the Axes plot method.
# Add data from the austin_weather DataFrame in a similar manner and call plt.show to show the results.'''
#
# # Import the matplotlib.pyplot submodule and name it plt
# ____
#
# # Create a Figure and an Axes with plt.subplots
# fig, ax = ____
#
# # Plot MLY-PRCP-NORMAL from seattle_weather against the MONTH
# ax.____(seattle_weather["MONTH"], ____)
#
# # Plot MLY-PRCP-NORMAL from austin_weather against MONTH
# ax.____(____, ____)
#
# # Call the show function
# ____
# ChatGPT
# Here's the solution to import matplotlib.pyplot, create Figure and Axes objects, and plot the rainfall data for Seattle and Austin:
#
# python
# Copy code
# # Import the matplotlib.pyplot submodule and name it plt
# import matplotlib.pyplot as plt
#
# # Create a Figure and an Axes with plt.subplots
# fig, ax = plt.subplots()
#
# # Plot MLY-PRCP-NORMAL from seattle_weather against the MONTH
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], label="Seattle")
#
# # Plot MLY-PRCP-NORMAL from austin_weather against MONTH
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], label="Austin")
#
# # Add a legend to distinguish between the two lines
# ax.legend()
#
# # Call the show function
# plt.show()

# %% [markdown]
# Your recent learnings
# When you left 14 hours ago, you worked on Introduction to Matplotlib, chapter 1 of the course Introduction to Data Visualization with Matplotlib. Here is what you covered in your last lesson:
#
# You learned about the basics of data visualization with Matplotlib, a powerful Python library for creating a wide range of static, animated, and interactive visualizations. Key points covered include:
#
# Introduction to Matplotlib: You discovered that Matplotlib allows for detailed control over plot properties, enabling the creation of both simple and complex visualizations.
# Importing Matplotlib: The convention of importing the matplotlib.pyplot submodule as plt was introduced, which is a widely adopted practice in the Python data science community.
# Creating Figures and Axes: You learned how to use plt.subplots() to create a Figure (the entire visualization) and Axes (the part of the Figure where data is plotted), which are fundamental to structuring your visualizations.
# Plotting Data: The process of adding data to an Axes object using the plot method was covered. You practiced plotting data from pandas DataFrames, specifically focusing on visualizing weather patterns in Seattle and Austin.
# Here's a snippet of code that encapsulates these concepts:
#
# import matplotlib.pyplot as plt
#
# # Create a Figure and an Axes with plt.subplots
# fig, ax = plt.subplots()
#
# # Plotting data on the Axes
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])
#
# # Display the plot
# plt.show()
# This code demonstrates the creation of a visualization comparing average monthly rainfall between Seattle and Austin, showcasing the practical application of the concepts you've learned.
#
# The goal of the next lesson is to learn about adding legends, gridlines, and text annotations to plots for better data interpretation and presentation.

# %%
# Plot Seattle data, setting data appearance
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], color='b', marker='o', linestyle='--')

# Plot Austin data, setting data appearance
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], color='r', marker='v', linestyle='--')

# Call show to display the resulting plot
plt.show()

# %% [markdown]
# '''Customizing data appearance
# We can customize the appearance of data in our plots, while adding the data to the plot, using key-word arguments to the plot command.
#
# In this exercise, you will customize the appearance of the markers, the linestyle that is used, and the color of the lines and markers for your data.
#
# As before, the data is already provided in pandas DataFrame objects loaded into memory: seattle_weather and austin_weather. These each have a "MONTHS" column and a "MLY-PRCP-NORMAL" that you will plot against each other.
#
# In addition, a Figure object named fig and an Axes object named ax have already been created for you.
#
# Instructions
# 100 XP
# Call ax.plot to plot "MLY-PRCP-NORMAL" against "MONTHS" in both DataFrames.
# Pass the color key-word arguments to these commands to set the color of the Seattle data to blue ('b') and the Austin data to red ('r').
# Pass the marker key-word arguments to these commands to set the Seattle data to circle markers ('o') and the Austin markers to triangles pointing downwards ('v').
# Pass the linestyle key-word argument to use dashed lines for the data from both cities ('--').'''
#
#
# # Plot Seattle data, setting data appearance
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], ____)
#
# # Plot Austin data, setting data appearance
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], ____)
#
# # Call show to display the resulting plot
# plt.show()
# ChatGPT
# To customize the appearance of the markers, linestyle, and color for your data, you can use the key-word arguments color, marker, and linestyle in the ax.plot function. Here is the complete code:
#
# python
# Copy code
# # Plot Seattle data, setting data appearance
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], color='b', marker='o', linestyle='--')
#
# # Plot Austin data, setting data appearance
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], color='r', marker='v', linestyle='--')
#
# # Call show to display the resulting plot
# plt.show()
# In this code:
#
# color='b' sets the color of the Seattle data to blue.
# marker='o' sets the markers for Seattle data to circles.
# color='r' sets the color of the Austin data to red.
# marker='v' sets the markers for Austin data to triangles pointing downwards.
# linestyle='--' uses dashed lines for both datasets.

# %%
# Plot Seattle data
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])

# Plot Austin data
ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])

# Customize the x-axis label
ax.set_xlabel("Time (months)")

# Customize the y-axis label
ax.set_ylabel("Precipitation (inches)")

# Add the title
ax.set_title("Weather patterns in Austin and Seattle")

# Display the figure
plt.show()

# %% [markdown]
# '''Customizing axis labels and adding titles
# Customizing the axis labels requires using the set_xlabel and set_ylabel methods of the Axes object. Adding a title uses the set_title method.
#
# In this exercise, you will customize the content of the axis labels and add a title to a plot.
#
# As before, the data is already provided in pandas DataFrame objects loaded into memory: seattle_weather and austin_weather. These each have a "MONTH" column and a "MLY-PRCP-NORMAL" column. These data are plotted against each other in the first two lines of the sample code provided.
#
# In addition, a Figure object named fig and an Axes object named ax have already been created for you.
#
# Instructions
# 100 XP
# Use the set_xlabel method to add the label: "Time (months)".
# Use the set_ylabel method to add the label: "Precipitation (inches)".
# Use the set_title method to add the title: "Weather patterns in Austin and Seattle".'''
#
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])
#
# # Customize the x-axis label
# ____
#
# # Customize the y-axis label
# ____
#
# # Add the title
# ____
#
# # Display the figure
# plt.show()
# ChatGPT
# To customize the axis labels and add a title, you can use the set_xlabel, set_ylabel, and set_title methods of the Axes object. Here is the complete code:
#
# python
# Copy code
# # Plot Seattle data
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
#
# # Plot Austin data
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])
#
# # Customize the x-axis label
# ax.set_xlabel("Time (months)")
#
# # Customize the y-axis label
# ax.set_ylabel("Precipitation (inches)")
#
# # Add the title
# ax.set_title("Weather patterns in Austin and Seattle")
#
# # Display the figure
# plt.show()
# In this code:
#
# ax.set_xlabel("Time (months)") sets the label for the x-axis.
# ax.set_ylabel("Precipitation (inches)") sets the label for the y-axis.
# ax.set_title("Weather patterns in Austin and Seattle") adds the title to the plot.

# %% [markdown]
# Creating a grid of subplots
# How would you create a Figure with 6 Axes objects organized in 3 rows and 2 columns?
#
# Instructions
# 50 XP
# Possible answers
#
#
# fig, ax = plt.subplots((3, 2))
#
# fig, ax = plt.axes((2, 3))
#
# fig, ax = plt.subplots(3, 2)
#
# fig, ax = plt.subplots((2, 3))
# ChatGPT
# The correct way to create a Figure with 6 Axes objects organized in 3 rows and 2 columns is:
#
# python
# Copy code
# fig, ax = plt.subplots(3, 2)
# This creates a grid of subplots with 3 rows and 2 columns.

# %%
# Create a Figure and an array of subplots with 2 rows and 2 columns
fig, ax = plt.subplots(2, 2)

# Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
ax[0, 0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
ax[0, 0].set_title('Seattle Precipitation')

# In the top right (index 0, 1), plot month and Seattle temperatures
ax[0, 1].plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
ax[0, 1].set_title('Seattle Temperature')

# In the bottom left (1, 0) plot month and Austin precipitation
ax[1, 0].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])
ax[1, 0].set_title('Austin Precipitation')

# In the bottom right (1, 1) plot month and Austin temperatures
ax[1, 1].plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
ax[1, 1].set_title('Austin Temperature')

# Display the figure
plt.show()

# %% [markdown]
# '''Creating small multiples with plt.subplots
# Small multiples are used to plot several datasets side-by-side. In Matplotlib, small multiples can be created using the plt.subplots() function. The first argument is the number of rows in the array of Axes objects generate and the second argument is the number of columns. In this exercise, you will use the Austin and Seattle data to practice creating and populating an array of subplots.
#
# The data is given to you in DataFrames: seattle_weather and austin_weather. These each have a "MONTH" column and "MLY-PRCP-NORMAL" (for average precipitation), as well as "MLY-TAVG-NORMAL" (for average temperature) columns. In this exercise, you will plot in a separate subplot the monthly average precipitation and average temperatures in each city.
#
# Instructions
# 100 XP
# Create a Figure and an array of subplots with 2 rows and 2 columns.
# Addressing the top left Axes as index 0, 0, plot the Seattle precipitation.
# In the top right (index 0,1), plot Seattle temperatures.
# In the bottom left (1, 0) and bottom right (1, 1) plot Austin precipitations and temperatures.'''
#
#
# # Create a Figure and an array of subplots with 2 rows and 2 columns
# fig, ax = plt.subplots(____, ____)
#
# # Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
# ax[0, 0].plot(____, ____)
#
# # In the top right (index 0,1), plot month and Seattle temperatures
# ax[0, 1].plot(____, ____)
#
# # In the bottom left (1, 0) plot month and Austin precipitations
# ax[____].plot(____, ____)
#
# # In the bottom right (1, 1) plot month and Austin temperatures
# ax[____].plot(____, ____)
# plt.show()
# ChatGPT
# Here's how you can create a Figure with an array of subplots, and plot the monthly average precipitation and temperatures for Seattle and Austin:
#
# python
# Copy code
# # Create a Figure and an array of subplots with 2 rows and 2 columns
# fig, ax = plt.subplots(2, 2)
#
# # Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
# ax[0, 0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
# ax[0, 0].set_title('Seattle Precipitation')
#
# # In the top right (index 0, 1), plot month and Seattle temperatures
# ax[0, 1].plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
# ax[0, 1].set_title('Seattle Temperature')
#
# # In the bottom left (1, 0) plot month and Austin precipitation
# ax[1, 0].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])
# ax[1, 0].set_title('Austin Precipitation')
#
# # In the bottom right (1, 1) plot month and Austin temperatures
# ax[1, 1].plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
# ax[1, 1].set_title('Austin Temperature')
#
# # Display the figure
# plt.show()
# This code creates a 2x2 grid of subplots and populates them with the specified data for Seattle and Austin. Each subplot is also given a title for clarity.

# %%
# Create a figure and an array of axes: 2 rows, 1 column with shared y axis
fig, ax = plt.subplots(2, 1, sharey=True)

# Plot Seattle precipitation data in the top axes
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], color='b')
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"], color='b', linestyle='--')
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"], color='b', linestyle='--')
ax[0].set_title('Seattle Precipitation')

# Plot Austin precipitation data in the bottom axes
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], color='r')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"], color='r', linestyle='--')
ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"], color='r', linestyle='--')
ax[1].set_title('Austin Precipitation')

plt.show()

# %% [markdown]
# '''Small multiples with shared y axis
# When creating small multiples, it is often preferable to make sure that the different plots are displayed with the same scale used on the y-axis. This can be configured by setting the sharey key-word to True.
#
# In this exercise, you will create a Figure with two Axes objects that share their y-axis. As before, the data is provided in seattle_weather and austin_weather DataFrames.
#
# Instructions
# 100 XP
# Create a Figure with an array of two Axes objects that share their y-axis range.
# Plot Seattle's "MLY-PRCP-NORMAL" in a solid blue line in the top Axes.
# Add Seattle's "MLY-PRCP-25PCTL" and "MLY-PRCP-75PCTL" in dashed blue lines to the top Axes.
# Plot Austin's "MLY-PRCP-NORMAL" in a solid red line in the bottom Axes and the "MLY-PRCP-25PCTL" and "MLY-PRCP-75PCTL" in dashed red lines.''''
#
#
# # Create a figure and an array of axes: 2 rows, 1 column with shared y axis
# fig, ax = plt.subplots(2, 1, sharey=True)
#
# # Plot Seattle precipitation data in the top axes
# ____.plot(____, ____, color = ____)
# ____.plot(____, ____, color = ____, linestyle = ____)
# ____.plot(____, ____, color = ____, linestyle = ____)
#
# # Plot Austin precipitation data in the bottom axes
# ____.plot(____, ____, color = ____)
# ____.plot(____, ____, color = ____, linestyle = ____)
# ____.plot(____, ____, color = ____, linestyle = ____)
#
# plt.show()
# ChatGPT
# Here's how you can create a Figure with two Axes objects that share their y-axis range and plot the specified precipitation data for Seattle and Austin:
#
# python
# Copy code
# # Create a figure and an array of axes: 2 rows, 1 column with shared y axis
# fig, ax = plt.subplots(2, 1, sharey=True)
#
# # Plot Seattle precipitation data in the top axes
# ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], color='b')
# ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"], color='b', linestyle='--')
# ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"], color='b', linestyle='--')
# ax[0].set_title('Seattle Precipitation')
#
# # Plot Austin precipitation data in the bottom axes
# ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], color='r')
# ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"], color='r', linestyle='--')
# ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"], color='r', linestyle='--')
# ax[1].set_title('Austin Precipitation')
#
# plt.show()
# In this code:
#
# fig, ax = plt.subplots(2, 1, sharey=True) creates a figure with two vertically stacked subplots that share the y-axis.
# ax[0] and ax[1] are used to address the top and bottom subplots, respectively.
# Solid and dashed lines are used to plot the normal, 25th percentile, and 75th percentile precipitation data for both cities.

# %%
# Import pandas as pd
import pandas as pd

# Read the data from file using read_csv
climate_change = pd.read_csv('climate_change.csv', parse_dates=['date'], index_col='date')

# %% [markdown]
#  both cities.
# '''Read data with a time index
# pandas DataFrame objects can have an index denoting time, this recognized by Matplotlib for axis labeling.
#
# This exercise involves reading data from climate_change.csv, containing CO2 levels and temperatures recorded on the 6th of each month from 1958 to 2016, using pandas' read_csv function. The parse_dates and index_col arguments help set a DateTimeIndex.
#
# Don't forget to check out the Matplotlib Cheat Sheet for a quick overview of essential concepts and methods.
#
# Instructions
# 100 XP
# Import the pandas library as pd.
# Read in the data from a CSV file called 'climate_change.csv' using pd.read_csv.
# Use the parse_dates key-word argument to parse the "date" column as dates.
# Use the index_col key-word argument to set the "date" column as the index.'''
#
#
# # Import pandas as pd
# ____
#
# # Read the data from file using read_csv
# climate_change = pd.read_csv(____, ____, ____)
# ChatGPT
# Here's how you can read the data from the CSV file climate_change.csv using pandas, ensuring the "date" column is parsed as dates and set as the index:
#
# python
# Copy code
# # Import pandas as pd
# import pandas as pd
#
# # Read the data from file using read_csv
# climate_change = pd.read_csv('climate_change.csv', parse_dates=['date'], index_col='date')
# In this code:
#
# import pandas as pd imports the pandas library.
# pd.read_csv('climate_change.csv', parse_dates=['date'], index_col='date') reads the data from climate_change.csv, parses the "date" column as dates, and sets it as the index of the DataFrame.

# %%
import matplotlib.pyplot as plt

# Create a figure and axes
fig, ax = plt.subplots()

# Add the time-series for "relative_temp" to the plot
ax.plot(climate_change.index, climate_change["relative_temp"])

# Set the x-axis label
ax.set_xlabel('Time')

# Set the y-axis label
ax.set_ylabel('Relative temperature (Celsius)')

# Show the figure
plt.show()

# %% [markdown]
# '''Plot time-series data
# To plot time-series data, we use the Axes object plot command. The first argument to this method are the values for the x-axis and the second argument are the values for the y-axis.
#
# This exercise provides data stored in a DataFrame called climate_change. This variable has a time-index with the dates of measurements and two data columns: "co2" and "relative_temp".
#
# In this case, the index of the DataFrame would be used as the x-axis values and we will plot the values stored in the "relative_temp" column as the y-axis values. We will also properly label the x-axis and y-axis.
#
# Instructions
# 100 XP
# Add the data from climate_change to the plot: use the DataFrame index for the x value and the "relative_temp" column for the y values.
# Set the x-axis label to 'Time'.
# Set the y-axis label to 'Relative temperature (Celsius)'.
# Show the figure.'''
#
#
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots()
#
# # Add the time-series for "relative_temp" to the plot
# ____
#
# # Set the x-axis label
# ____
#
# # Set the y-axis label
# ____
#
# # Show the figure
# ____
# ChatGPT
# Here's how you can plot the time-series data from the climate_change DataFrame, setting the appropriate axis labels and displaying the figure:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Add the time-series for "relative_temp" to the plot
# ax.plot(climate_change.index, climate_change["relative_temp"])
#
# # Set the x-axis label
# ax.set_xlabel('Time')
#
# # Set the y-axis label
# ax.set_ylabel('Relative temperature (Celsius)')
#
# # Show the figure
# plt.show()
# In this code:
#
# ax.plot(climate_change.index, climate_change["relative_temp"]) adds the time-series data to the plot using the DataFrame index for the x values and the "relative_temp" column for the y values.
# ax.set_xlabel('Time') sets the label for the x-axis.
# ax.set_ylabel('Relative temperature (Celsius)') sets the label for the y-axis.
# plt.show() displays the figure.

# %%
import matplotlib.pyplot as plt

# Use plt.subplots to create fig and ax
fig, ax = plt.subplots()

# Create variable seventies with data from "1970-01-01" to "1979-12-31"
seventies = climate_change["1970-01-01":"1979-12-31"]

# Add the time-series for "co2" data from seventies to the plot
ax.plot(seventies.index, seventies["co2"])

# Show the figure
plt.show()

# %% [markdown]
# the figure.
# '''Using a time index to zoom in
# When a time-series is represented with a time index, we can use this index for the x-axis when plotting. We can also select a range of dates to zoom in on a particular period within the time-series using pandas' indexing facilities. In this exercise, you will select a portion of a time-series dataset and you will plot that period.
#
# The data to use is stored in a DataFrame called climate_change, which has a time-index with dates of measurements and two data columns: "co2" and "relative_temp".
#
# Instructions
# 100 XP
# Use plt.subplots to create a Figure with one Axes called fig and ax, respectively.
# Create a variable called seventies that includes all the data between "1970-01-01" and "1979-12-31".
# Add the data from seventies to the plot: use the DataFrame index for the x value and the "co2" column for the y values.'''
#
#
#
# import matplotlib.pyplot as plt
#
# # Use plt.subplots to create fig and ax
# ____
#
# # Create variable seventies with data from "1970-01-01" to "1979-12-31"
# seventies = climate_change[____]
#
# # Add the time-series for "co2" data from seventies to the plot
# ____(____, ____["co2"])
#
# # Show the figure
# ____
# ChatGPT
# Here's how you can create a plot that zooms in on the 1970s and displays the CO2 data:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Use plt.subplots to create fig and ax
# fig, ax = plt.subplots()
#
# # Create variable seventies with data from "1970-01-01" to "1979-12-31"
# seventies = climate_change["1970-01-01":"1979-12-31"]
#
# # Add the time-series for "co2" data from seventies to the plot
# ax.plot(seventies.index, seventies["co2"])
#
# # Show the figure
# plt.show()
# In this code:
#
# fig, ax = plt.subplots() creates a figure and a single axes.
# seventies = climate_change["1970-01-01":"1979-12-31"] selects the data between January 1, 1970, and December 31, 1979.
# ax.plot(seventies.index, seventies["co2"]) adds the CO2 data from the 1970s to the plot using the DataFrame index for the x values and the "co2" column for the y values.
# plt.show() displays the figure.

# %%
import matplotlib.pyplot as plt

# Initialize a Figure and Axes
fig, ax = plt.subplots()

# Plot the CO2 variable in blue
ax.plot(climate_change.index, climate_change["co2"], color='blue')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature in red
ax2.plot(climate_change.index, climate_change["relative_temp"], color='red')

plt.show()

# %% [markdown]
# '''Plotting two variables
# If you want to plot two time-series variables that were recorded at the same times, you can add both of them to the same subplot.
#
# If the variables have very different scales, you'll want to make sure that you plot them in different twin Axes objects. These objects can share one axis (for example, the time, or x-axis) while not sharing the other (the y-axis).
#
# To create a twin Axes object that shares the x-axis, we use the twinx method.
#
# In this exercise, you'll have access to a DataFrame that has the climate_change data loaded into it. This DataFrame was loaded with the "date" column set as a DateTimeIndex, and it has a column called "co2" with carbon dioxide measurements and a column called "relative_temp" with temperature measurements.
#
# Instructions
# 100 XP
# Use plt.subplots to create a Figure and Axes objects called fig and ax, respectively.
# Plot the carbon dioxide variable in blue using the Axes plot method.
# Use the Axes twinx method to create a twin Axes that shares the x-axis.
# Plot the relative temperature variable in red on the twin Axes using its plot method.'''
#
#
# import matplotlib.pyplot as plt
#
# # Initalize a Figure and Axes
# ____
#
# # Plot the CO2 variable in blue
# ax.plot(____, ____, color=____)
#
# # Create a twin Axes that shares the x-axis
# ax2 = ____
#
# # Plot the relative temperature in red
# ____.plot(____, ____, color=____)
#
# plt.show()
# ChatGPT
# Here's how you can plot two time-series variables on the same subplot using twin Axes objects:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Initialize a Figure and Axes
# fig, ax = plt.subplots()
#
# # Plot the CO2 variable in blue
# ax.plot(climate_change.index, climate_change["co2"], color='blue')
#
# # Create a twin Axes that shares the x-axis
# ax2 = ax.twinx()
#
# # Plot the relative temperature in red
# ax2.plot(climate_change.index, climate_change["relative_temp"], color='red')
#
# plt.show()
# In this code:
#
# fig, ax = plt.subplots() initializes a figure and a single axes.
# ax.plot(climate_change.index, climate_change["co2"], color='blue') plots the CO2 data in blue.
# ax.twinx() creates a twin axes that shares the x-axis with the original axes.
# ax2.plot(climate_change.index, climate_change["relative_temp"], color='red') plots the relative temperature data in red on the twin axes.
# plt.show() displays the figure.

# %%
# Define a function called plot_timeseries
def plot_timeseries(axes, x, y, color, xlabel, ylabel):
    # Plot the inputs x, y in the provided color
    axes.plot(x, y, color=color)
    
    # Set the x-axis label
    axes.set_xlabel(xlabel)
    
    # Set the y-axis label
    axes.set_ylabel(ylabel, color=color)
    
    # Set the y-axis tick parameters
    axes.tick_params('y', colors=color)

# %% [markdown]
# '''Defining a function that plots time-series data
# Once you realize that a particular section of code that you have written is useful, it is a good idea to define a function that saves that section of code for you, rather than copying it to other parts of your program where you would like to use this code.
#
# Here, we will define a function that takes inputs such as a time variable and some other variable and plots them as x and y inputs. Then, it sets the labels on the x- and y-axis and sets the colors of the y-axis label, the y-axis ticks and the tick labels.
#
# Instructions
# 100 XP
# Define a function called plot_timeseries that takes as input an Axes object (axes), data (x,y), a string with the name of a color and strings for x- and y-axis labels.
# Plot y as a function of in the color provided as the input color.
# Set the x- and y-axis labels using the provided input xlabel and ylabel, setting the y-axis label color using color.
# Set the y-axis tick parameters using the tick_params method of the Axes object, setting the colors key-word to color.'''
#
#
# # Define a function called plot_timeseries
# def ____(axes, x, y, color, xlabel, ylabel):
#
#   # Plot the inputs x,y in the provided color
#   axes.____(____, ____, color=____)
#
#   # Set the x-axis label
#   ____.____(____)
#
#   # Set the y-axis label
#   ____.____(____, color=____)
#
#   # Set the colors tick params for y-axis
#   ____.____('y', colors=____)
# ChatGPT
# Here's how you can define the plot_timeseries function to plot time-series data and set the axis labels and tick parameters:
#
# python
# Copy code
# # Define a function called plot_timeseries
# def plot_timeseries(axes, x, y, color, xlabel, ylabel):
#     # Plot the inputs x, y in the provided color
#     axes.plot(x, y, color=color)
#
#     # Set the x-axis label
#     axes.set_xlabel(xlabel)
#
#     # Set the y-axis label
#     axes.set_ylabel(ylabel, color=color)
#
#     # Set the y-axis tick parameters
#     axes.tick_params('y', colors=color)
# In this function:
#
# axes.plot(x, y, color=color) plots the x and y data on the provided axes using the specified color.
# axes.set_xlabel(xlabel) sets the label for the x-axis.
# axes.set_ylabel(ylabel, color=color) sets the label for the y-axis and colors it with the specified color.
# axes.tick_params('y', colors=color) sets the tick parameters for the y-axis, coloring the ticks and tick labels with the specified color.

# %%
fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, climate_change.index, climate_change["co2"], "blue", "Time (years)", "CO2 levels")

# Create a twin Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], "red", "Time (years)", "Relative temperature (Celsius)")

plt.show()

# %% [markdown]
# '''Using a plotting function
# Defining functions allows us to reuse the same code without having to repeat all of it. Programmers sometimes say "Don't repeat yourself".
#
# In the previous exercise, you defined a function called plot_timeseries:
#
# plot_timeseries(axes, x, y, color, xlabel, ylabel)
# that takes an Axes object (as the argument axes), time-series data (as x and y arguments) the name of a color (as a string, provided as the color argument) and x-axis and y-axis labels (as xlabel and ylabel arguments). In this exercise, the function plot_timeseries is already defined and provided to you.
#
# Use this function to plot the climate_change time-series data, provided as a pandas DataFrame object that has a DateTimeIndex with the dates of the measurements and co2 and relative_temp columns.
#
# Instructions
# 100 XP
# In the provided ax object, use the function plot_timeseries to plot the "co2" column in blue, with the x-axis label "Time (years)" and y-axis label "CO2 levels".
# Use the ax.twinx method to add an Axes object to the figure that shares the x-axis with ax.
# Use the function plot_timeseries to add the data in the "relative_temp" column in red to the twin Axes object, with the x-axis label "Time (years)" and y-axis label "Relative temperature (Celsius)".''''
#
#
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# ____(____, ____, ____, "blue", ____, ____)
#
# # Create a twin Axes object that shares the x-axis
# ax2 = ____
#
# # Plot the relative temperature data in red
# ____(____, ____, ____, "red", ____, ____)
#
# plt.show()
# ChatGPT
# Here's how you can use the plot_timeseries function to plot the climate_change data for CO2 levels and relative temperature:
#
# python
# Copy code
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# plot_timeseries(ax, climate_change.index, climate_change["co2"], "blue", "Time (years)", "CO2 levels")
#
# # Create a twin Axes object that shares the x-axis
# ax2 = ax.twinx()
#
# # Plot the relative temperature data in red
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], "red", "Time (years)", "Relative temperature (Celsius)")
#
# plt.show()
# In this code:
#
# plot_timeseries(ax, climate_change.index, climate_change["co2"], "blue", "Time (years)", "CO2 levels") plots the CO2 levels on the primary axes in blue.
# ax.twinx() creates a twin axes that shares the x-axis with the original axes.
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], "red", "Time (years)", "Relative temperature (Celsius)") plots the relative temperature data on the twin axes in red.
# plt.show() displays the figure.

# %%
import pandas as pd

fig, ax = plt.subplots()

# Plot the relative temperature data
ax.plot(climate_change.index, climate_change["relative_temp"])

# Annotate the date at which temperatures exceeded 1 degree
ax.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05))

plt.show()

# %% [markdown]
# s the figure.
# '''Annotating a plot of time-series data
# Annotating a plot allows us to highlight interesting information in the plot. For example, in describing the climate change dataset, we might want to point to the date at which the relative temperature first exceeded 1 degree Celsius.
#
# For this, we will use the annotate method of the Axes object. In this exercise, you will have the DataFrame called climate_change loaded into memory. Using the Axes methods, plot only the relative temperature column as a function of dates, and annotate the data.
#
# Instructions
# 100 XP
# Use the ax.plot method to plot the DataFrame index against the relative_temp column.
# Use the annotate method to add the text '>1 degree' in the location (pd.Timestamp('2015-10-06'), 1).'''
#
#
#
# fig, ax = plt.subplots()
#
# # Plot the relative temperature data
# ____
#
# # Annotate the date at which temperatures exceeded 1 degree
# ax.____(____, ____)
#
# plt.show()
# ChatGPT
# Here's how you can annotate a plot of the relative_temp column in the climate_change DataFrame to highlight the date at which the relative temperature first exceeded 1 degree Celsius:
#
# python
# Copy code
# import pandas as pd
#
# fig, ax = plt.subplots()
#
# # Plot the relative temperature data
# ax.plot(climate_change.index, climate_change["relative_temp"])
#
# # Annotate the date at which temperatures exceeded 1 degree
# ax.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), 1.5),
#             arrowprops=dict(facecolor='black', shrink=0.05))
#
# plt.show()
# In this code:
#
# ax.plot(climate_change.index, climate_change["relative_temp"]) plots the relative temperature data.
# ax.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), 1.5), arrowprops=dict(facecolor='black', shrink=0.05)) adds the annotation ">1 degree" at the specified location with an arrow pointing to it.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Function to plot time-series data
def plot_timeseries(axes, x, y, color, xlabel, ylabel):
    axes.plot(x, y, color=color)
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel, color=color)
    axes.tick_params('y', colors=color)

fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', 'Time (years)', 'CO2 levels')

# Create an Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], 'red', 'Time (years)', 'Relative temp (Celsius)')

# Annotate point with relative temperature >1 degree
ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), -0.2),
             arrowprops=dict(arrowstyle='->', color='gray'))

plt.show()

# %% [markdown]
# '''Plotting time-series: putting it all together
# In this exercise, you will plot two time-series with different scales on the same Axes, and annotate the data from one of these series.
#
# The CO2/temperatures data is provided as a DataFrame called climate_change. You should also use the function that we have defined before, called plot_timeseries, which takes an Axes object (as the axes argument) plots a time-series (provided as x and y arguments), sets the labels for the x-axis and y-axis and sets the color for the data, and for the y tick/axis labels:
#
# plot_timeseries(axes, x, y, color, xlabel, ylabel)
# Then, you will annotate with text an important time-point in the data: on 2015-10-06, when the temperature first rose to above 1 degree over the average.
#
# Instructions
# 100 XP
# Use the plot_timeseries function to plot CO2 levels against time. Set xlabel to "Time (years)" ylabel to "CO2 levels" and color to 'blue'.
# Create ax2, as a twin of the first Axes.
# In ax2, plot temperature against time, setting the color ylabel to "Relative temp (Celsius)" and color to 'red'.
# Annotate the data using the ax2.annotate method. Place the text ">1 degree" in x=pd.Timestamp('2008-10-06'), y=-0.2 pointing with a gray thin arrow to x=pd.Timestamp('2015-10-06'), y = 1.'''
#
#
#
#
#
#
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# plot_timeseries(____, ____, ____, 'blue', ____, ____)
#
# # Create an Axes object that shares the x-axis
# ax2 = ____
#
# # Plot the relative temperature data in red
# plot_timeseries(____, ____, ____, 'red', ____, ____)
#
# # Annotate point with relative temperature >1 degree
# ax2.____(">1 degree", ____, ____, ____)
#
# plt.show()
# ChatGPT
# Here's how you can plot the CO2 levels and relative temperature time-series on the same plot with different y-axes and annotate the point where the temperature first exceeded 1 degree Celsius:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Function to plot time-series data
# def plot_timeseries(axes, x, y, color, xlabel, ylabel):
#     axes.plot(x, y, color=color)
#     axes.set_xlabel(xlabel)
#     axes.set_ylabel(ylabel, color=color)
#     axes.tick_params('y', colors=color)
#
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', 'Time (years)', 'CO2 levels')
#
# # Create an Axes object that shares the x-axis
# ax2 = ax.twinx()
#
# # Plot the relative temperature data in red
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], 'red', 'Time (years)', 'Relative temp (Celsius)')
#
# # Annotate point with relative temperature >1 degree
# ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), -0.2),
#              arrowprops=dict(facecolor='gray', shrink=0.05))
#
# plt.show()
# In this code:
#
# plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', 'Time (years)', 'CO2 levels') plots the CO2 levels with the color blue and appropriate labels.
# ax2 = ax.twinx() creates a second y-axis that shares the same x-axis.
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], 'red', 'Time (years)', 'Relative temp (Celsius)') plots the relative temperature data on the second y-axis with the color red and appropriate labels.
# ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), -0.2), arrowprops=dict(facecolor='gray', shrink=0.05)) adds an annotation with an arrow pointing to the date when the temperature first exceeded 1 degree Celsius.
# Incorrect submission
# Check your call of ax2.annotate(). Did you correctly specify the argument arrowprops? Expected {'arrowstyle': '->', 'color': 'gray'}, but got {'facecolor': 'gray', 'shrink': 0.05}.
# ChatGPT
# It looks like I specified the wrong arrowprops in the annotate method. Let's correct it with the expected arrowstyle and color.
#
# Here's the corrected code:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Function to plot time-series data
# def plot_timeseries(axes, x, y, color, xlabel, ylabel):
#     axes.plot(x, y, color=color)
#     axes.set_xlabel(xlabel)
#     axes.set_ylabel(ylabel, color=color)
#     axes.tick_params('y', colors=color)
#
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', 'Time (years)', 'CO2 levels')
#
# # Create an Axes object that shares the x-axis
# ax2 = ax.twinx()
#
# # Plot the relative temperature data in red
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], 'red', 'Time (years)', 'Relative temp (Celsius)')
#
# # Annotate point with relative temperature >1 degree
# ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), -0.2),
#              arrowprops=dict(arrowstyle='->', color='gray'))
#
# plt.show()
# In this version:
#
# The arrowprops argument in the annotate method now uses arrowstyle='->' and color='gray' to match the expected specification.

# %%
# Quantitative comparisons and statistical visualizations
# Visualizations can be used to compare data in a quantitative manner. This chapter explains several methods for quantitative visualizations.
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Plot a bar-chart of gold medals as a function of country
ax.bar(medals.index, medals["Gold"])

# Set the x-axis tick labels to the country names and rotate them by 90 degrees
ax.set_xticklabels(medals.index, rotation=90)

# Set the y-axis label
ax.set_ylabel("Number of medals")

plt.show()

# %% [markdown]
# '''Bar chart
# Bar charts visualize data that is organized according to categories as a series of bars, where the height of each bar represents the values of the data in this category.
#
# For example, in this exercise, you will visualize the number of gold medals won by each country in the provided medals DataFrame. The DataFrame contains the countries as the index, and a column called "Gold" that contains the number of gold medals won by each country, according to their rows.
#
# Instructions
# 100 XP
# Call the ax.bar method to plot the "Gold" column as a function of the country.
# Use the ax.set_xticklabels to set the x-axis tick labels to be the country names.
# In the call to ax.set_xticklabels rotate the x-axis tick labels by 90 degrees by using the rotation key-word argument.
# Set the y-axis label to "Number of medals".'''
#
#
# fig, ax = plt.subplots()
#
# # Plot a bar-chart of gold medals as a function of country
# ____
#
# # Set the x-axis tick labels to the country names
# ____.set_xticklabels(____, ____)
#
# # Set the y-axis label
# ____
#
# plt.show()
# ChatGPT
# Here is the corrected code to create a bar chart, set the x-axis tick labels, and rotate them by 90 degrees:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots()
#
# # Plot a bar-chart of gold medals as a function of country
# ax.bar(medals.index, medals["Gold"])
#
# # Set the x-axis tick labels to the country names and rotate them by 90 degrees
# ax.set_xticklabels(medals.index, rotation=90)
#
# # Set the y-axis label
# ax.set_ylabel("Number of medals")
#
# plt.show()
# In this code:
#
# The ax.bar method is used to plot the gold medals as a function of the country.
# The ax.set_xticklabels method is used to set the x-axis tick labels to the country names and rotate them by 90 degrees.
# The ax.set_ylabel method is used to set the y-axis label to "Number of medals".

# %%
import matplotlib.pyplot as plt

# Assuming medals is a DataFrame with columns "Gold", "Silver", and "Bronze"
# and an index that holds the names of different countries

fig, ax = plt.subplots()

# Add bars for "Gold" with the label "Gold"
ax.bar(medals.index, medals["Gold"], label="Gold")

# Stack bars for "Silver" on top with label "Silver"
ax.bar(medals.index, medals["Silver"], bottom=medals["Gold"], label="Silver")

# Stack bars for "Bronze" on top of that with label "Bronze"
ax.bar(medals.index, medals["Bronze"], bottom=medals["Gold"] + medals["Silver"], label="Bronze")

# Display the legend
ax.legend()

plt.show()

# %% [markdown]
# '''Stacked bar chart
# A stacked bar chart contains bars, where the height of each bar represents values. In addition, stacked on top of the first variable may be another variable. The additional height of this bar represents the value of this variable. And you can add more bars on top of that.
#
# In this exercise, you will have access to a DataFrame called medals that contains an index that holds the names of different countries, and three columns: "Gold", "Silver" and "Bronze". You will also have a Figure, fig, and Axes, ax, that you can add data to.
#
# You will create a stacked bar chart that shows the number of gold, silver, and bronze medals won by each country, and you will add labels and create a legend that indicates which bars represent which medals.
#
# Instructions
# 100 XP
# Call the ax.bar method to add the "Gold" medals. Call it with the label set to "Gold".
# Call the ax.bar method to stack "Silver" bars on top of that, using the bottom key-word argument so the bottom of the bars will be on top of the gold medal bars, and label to add the label "Silver".
# Use ax.bar to add "Bronze" bars on top of that, using the bottom key-word and label it as "Bronze".'''
#
# # Add bars for "Gold" with the label "Gold"
# ____(____, ____, label=____)
#
# # Stack bars for "Silver" on top with label "Silver"
# ____(____, ____, bottom=____, ____)
#
# # Stack bars for "Bronze" on top of that with label "Bronze"
# ____
#
# # Display the legend
# ax.legend()
#
# plt.show()
# ChatGPT
# Here is the complete code to create a stacked bar chart showing the number of gold, silver, and bronze medals won by each country:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Assuming medals is a DataFrame with columns "Gold", "Silver", and "Bronze"
# # and an index that holds the names of different countries
#
# fig, ax = plt.subplots()
#
# # Add bars for "Gold" with the label "Gold"
# ax.bar(medals.index, medals["Gold"], label="Gold")
#
# # Stack bars for "Silver" on top with label "Silver"
# ax.bar(medals.index, medals["Silver"], bottom=medals["Gold"], label="Silver")
#
# # Stack bars for "Bronze" on top of that with label "Bronze"
# ax.bar(medals.index, medals["Bronze"], bottom=medals["Gold"] + medals["Silver"], label="Bronze")
#
# # Display the legend
# ax.legend()
#
# plt.show()
# In this code:
#
# The ax.bar method is used to create the gold medal bars.
# The bottom keyword argument is used to stack the silver medal bars on top of the gold medal bars.
# The bottom keyword argument is again used to stack the bronze medal bars on top of the combined height of the gold and silver bars.
# The ax.legend() method is used to display the legend.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing["Weight"], bins=15, alpha=0.7, label='Rowing')

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics["Weight"], bins=15, alpha=0.7, label='Gymnastics')

# Set the x-axis label to "Weight (kg)"
ax.set_xlabel("Weight (kg)")

# Set the y-axis label to "# of observations"
ax.set_ylabel("# of observations")

# Add a legend to differentiate the histograms
ax.legend()

plt.show()

# %% [markdown]
# '''Customizing data appearance
# We can customize the appearance of data in our plots, while adding the data to the plot, using key-word arguments to the plot command.
#
# In this exercise, you will customize the appearance of the markers, the linestyle that is used, and the color of the lines and markers for your data.
#
# As before, the data is already provided in pandas DataFrame objects loaded into memory: seattle_weather and austin_weather. These each have a "MONTHS" column and a "MLY-PRCP-NORMAL" that you will plot against each other.
#
# In addition, a Figure object named fig and an Axes object named ax have already been created for you.
#
# Instructions
# 100 XP
# Call ax.plot to plot "MLY-PRCP-NORMAL" against "MONTHS" in both DataFrames.
# Pass the color key-word arguments to these commands to set the color of the Seattle data to blue ('b') and the Austin data to red ('r').
# Pass the marker key-word arguments to these commands to set the Seattle data to circle markers ('o') and the Austin markers to triangles pointing downwards ('v').
# Pass the linestyle key-word argument to use dashed lines for the data from both cities ('--').'''
#
#
# # Plot Seattle data, setting data appearance
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], ____)
#
# # Plot Austin data, setting data appearance
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], ____)
#
# # Call show to display the resulting plot
# plt.show()
# ChatGPT
# To customize the appearance of the markers, linestyle, and color for your data, you can use the key-word arguments color, marker, and linestyle in the ax.plot function. Here is the complete code:
#
# python
# Copy code
# # Plot Seattle data, setting data appearance
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], color='b', marker='o', linestyle='--')
#
# # Plot Austin data, setting data appearance
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], color='r', marker='v', linestyle='--')
#
# # Call show to display the resulting plot
# plt.show()
# In this code:
#
# color='b' sets the color of the Seattle data to blue.
# marker='o' sets the markers for Seattle data to circles.
# color='r' sets the color of the Austin data to red.
# marker='v' sets the markers for Austin data to triangles pointing downwards.
# linestyle='--' uses dashed lines for both datasets.
# '''Customizing axis labels and adding titles
# Customizing the axis labels requires using the set_xlabel and set_ylabel methods of the Axes object. Adding a title uses the set_title method.
#
# In this exercise, you will customize the content of the axis labels and add a title to a plot.
#
# As before, the data is already provided in pandas DataFrame objects loaded into memory: seattle_weather and austin_weather. These each have a "MONTH" column and a "MLY-PRCP-NORMAL" column. These data are plotted against each other in the first two lines of the sample code provided.
#
# In addition, a Figure object named fig and an Axes object named ax have already been created for you.
#
# Instructions
# 100 XP
# Use the set_xlabel method to add the label: "Time (months)".
# Use the set_ylabel method to add the label: "Precipitation (inches)".
# Use the set_title method to add the title: "Weather patterns in Austin and Seattle".'''
#
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])
#
# # Customize the x-axis label
# ____
#
# # Customize the y-axis label
# ____
#
# # Add the title
# ____
#
# # Display the figure
# plt.show()
# ChatGPT
# To customize the axis labels and add a title, you can use the set_xlabel, set_ylabel, and set_title methods of the Axes object. Here is the complete code:
#
# python
# Copy code
# # Plot Seattle data
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
#
# # Plot Austin data
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])
#
# # Customize the x-axis label
# ax.set_xlabel("Time (months)")
#
# # Customize the y-axis label
# ax.set_ylabel("Precipitation (inches)")
#
# # Add the title
# ax.set_title("Weather patterns in Austin and Seattle")
#
# # Display the figure
# plt.show()
# In this code:
#
# ax.set_xlabel("Time (months)") sets the label for the x-axis.
# ax.set_ylabel("Precipitation (inches)") sets the label for the y-axis.
# ax.set_title("Weather patterns in Austin and Seattle") adds the title to the plot.
# Creating a grid of subplots
# How would you create a Figure with 6 Axes objects organized in 3 rows and 2 columns?
#
# Instructions
# 50 XP
# Possible answers
#
#
# fig, ax = plt.subplots((3, 2))
#
# fig, ax = plt.axes((2, 3))
#
# fig, ax = plt.subplots(3, 2)
#
# fig, ax = plt.subplots((2, 3))
# ChatGPT
# The correct way to create a Figure with 6 Axes objects organized in 3 rows and 2 columns is:
#
# python
# Copy code
# fig, ax = plt.subplots(3, 2)
# This creates a grid of subplots with 3 rows and 2 columns.
#
# '''Creating small multiples with plt.subplots
# Small multiples are used to plot several datasets side-by-side. In Matplotlib, small multiples can be created using the plt.subplots() function. The first argument is the number of rows in the array of Axes objects generate and the second argument is the number of columns. In this exercise, you will use the Austin and Seattle data to practice creating and populating an array of subplots.
#
# The data is given to you in DataFrames: seattle_weather and austin_weather. These each have a "MONTH" column and "MLY-PRCP-NORMAL" (for average precipitation), as well as "MLY-TAVG-NORMAL" (for average temperature) columns. In this exercise, you will plot in a separate subplot the monthly average precipitation and average temperatures in each city.
#
# Instructions
# 100 XP
# Create a Figure and an array of subplots with 2 rows and 2 columns.
# Addressing the top left Axes as index 0, 0, plot the Seattle precipitation.
# In the top right (index 0,1), plot Seattle temperatures.
# In the bottom left (1, 0) and bottom right (1, 1) plot Austin precipitations and temperatures.'''
#
#
# # Create a Figure and an array of subplots with 2 rows and 2 columns
# fig, ax = plt.subplots(____, ____)
#
# # Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
# ax[0, 0].plot(____, ____)
#
# # In the top right (index 0,1), plot month and Seattle temperatures
# ax[0, 1].plot(____, ____)
#
# # In the bottom left (1, 0) plot month and Austin precipitations
# ax[____].plot(____, ____)
#
# # In the bottom right (1, 1) plot month and Austin temperatures
# ax[____].plot(____, ____)
# plt.show()
# ChatGPT
# Here's how you can create a Figure with an array of subplots, and plot the monthly average precipitation and temperatures for Seattle and Austin:
#
# python
# Copy code
# # Create a Figure and an array of subplots with 2 rows and 2 columns
# fig, ax = plt.subplots(2, 2)
#
# # Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
# ax[0, 0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"])
# ax[0, 0].set_title('Seattle Precipitation')
#
# # In the top right (index 0, 1), plot month and Seattle temperatures
# ax[0, 1].plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
# ax[0, 1].set_title('Seattle Temperature')
#
# # In the bottom left (1, 0) plot month and Austin precipitation
# ax[1, 0].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"])
# ax[1, 0].set_title('Austin Precipitation')
#
# # In the bottom right (1, 1) plot month and Austin temperatures
# ax[1, 1].plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
# ax[1, 1].set_title('Austin Temperature')
#
# # Display the figure
# plt.show()
# This code creates a 2x2 grid of subplots and populates them with the specified data for Seattle and Austin. Each subplot is also given a title for clarity.
#
# '''Small multiples with shared y axis
# When creating small multiples, it is often preferable to make sure that the different plots are displayed with the same scale used on the y-axis. This can be configured by setting the sharey key-word to True.
#
# In this exercise, you will create a Figure with two Axes objects that share their y-axis. As before, the data is provided in seattle_weather and austin_weather DataFrames.
#
# Instructions
# 100 XP
# Create a Figure with an array of two Axes objects that share their y-axis range.
# Plot Seattle's "MLY-PRCP-NORMAL" in a solid blue line in the top Axes.
# Add Seattle's "MLY-PRCP-25PCTL" and "MLY-PRCP-75PCTL" in dashed blue lines to the top Axes.
# Plot Austin's "MLY-PRCP-NORMAL" in a solid red line in the bottom Axes and the "MLY-PRCP-25PCTL" and "MLY-PRCP-75PCTL" in dashed red lines.''''
#
#
# # Create a figure and an array of axes: 2 rows, 1 column with shared y axis
# fig, ax = plt.subplots(2, 1, sharey=True)
#
# # Plot Seattle precipitation data in the top axes
# ____.plot(____, ____, color = ____)
# ____.plot(____, ____, color = ____, linestyle = ____)
# ____.plot(____, ____, color = ____, linestyle = ____)
#
# # Plot Austin precipitation data in the bottom axes
# ____.plot(____, ____, color = ____)
# ____.plot(____, ____, color = ____, linestyle = ____)
# ____.plot(____, ____, color = ____, linestyle = ____)
#
# plt.show()
# ChatGPT
# Here's how you can create a Figure with two Axes objects that share their y-axis range and plot the specified precipitation data for Seattle and Austin:
#
# python
# Copy code
# # Create a figure and an array of axes: 2 rows, 1 column with shared y axis
# fig, ax = plt.subplots(2, 1, sharey=True)
#
# # Plot Seattle precipitation data in the top axes
# ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], color='b')
# ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"], color='b', linestyle='--')
# ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"], color='b', linestyle='--')
# ax[0].set_title('Seattle Precipitation')
#
# # Plot Austin precipitation data in the bottom axes
# ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"], color='r')
# ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"], color='r', linestyle='--')
# ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"], color='r', linestyle='--')
# ax[1].set_title('Austin Precipitation')
#
# plt.show()
# In this code:
#
# fig, ax = plt.subplots(2, 1, sharey=True) creates a figure with two vertically stacked subplots that share the y-axis.
# ax[0] and ax[1] are used to address the top and bottom subplots, respectively.
# Solid and dashed lines are used to plot the normal, 25th percentile, and 75th percentile precipitation data for both cities.
# '''Read data with a time index
# pandas DataFrame objects can have an index denoting time, this recognized by Matplotlib for axis labeling.
#
# This exercise involves reading data from climate_change.csv, containing CO2 levels and temperatures recorded on the 6th of each month from 1958 to 2016, using pandas' read_csv function. The parse_dates and index_col arguments help set a DateTimeIndex.
#
# Don't forget to check out the Matplotlib Cheat Sheet for a quick overview of essential concepts and methods.
#
# Instructions
# 100 XP
# Import the pandas library as pd.
# Read in the data from a CSV file called 'climate_change.csv' using pd.read_csv.
# Use the parse_dates key-word argument to parse the "date" column as dates.
# Use the index_col key-word argument to set the "date" column as the index.'''
#
#
# # Import pandas as pd
# ____
#
# # Read the data from file using read_csv
# climate_change = pd.read_csv(____, ____, ____)
# ChatGPT
# Here's how you can read the data from the CSV file climate_change.csv using pandas, ensuring the "date" column is parsed as dates and set as the index:
#
# python
# Copy code
# # Import pandas as pd
# import pandas as pd
#
# # Read the data from file using read_csv
# climate_change = pd.read_csv('climate_change.csv', parse_dates=['date'], index_col='date')
# In this code:
#
# import pandas as pd imports the pandas library.
# pd.read_csv('climate_change.csv', parse_dates=['date'], index_col='date') reads the data from climate_change.csv, parses the "date" column as dates, and sets it as the index of the DataFrame.
# '''Plot time-series data
# To plot time-series data, we use the Axes object plot command. The first argument to this method are the values for the x-axis and the second argument are the values for the y-axis.
#
# This exercise provides data stored in a DataFrame called climate_change. This variable has a time-index with the dates of measurements and two data columns: "co2" and "relative_temp".
#
# In this case, the index of the DataFrame would be used as the x-axis values and we will plot the values stored in the "relative_temp" column as the y-axis values. We will also properly label the x-axis and y-axis.
#
# Instructions
# 100 XP
# Add the data from climate_change to the plot: use the DataFrame index for the x value and the "relative_temp" column for the y values.
# Set the x-axis label to 'Time'.
# Set the y-axis label to 'Relative temperature (Celsius)'.
# Show the figure.'''
#
#
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots()
#
# # Add the time-series for "relative_temp" to the plot
# ____
#
# # Set the x-axis label
# ____
#
# # Set the y-axis label
# ____
#
# # Show the figure
# ____
# ChatGPT
# Here's how you can plot the time-series data from the climate_change DataFrame, setting the appropriate axis labels and displaying the figure:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Create a figure and axes
# fig, ax = plt.subplots()
#
# # Add the time-series for "relative_temp" to the plot
# ax.plot(climate_change.index, climate_change["relative_temp"])
#
# # Set the x-axis label
# ax.set_xlabel('Time')
#
# # Set the y-axis label
# ax.set_ylabel('Relative temperature (Celsius)')
#
# # Show the figure
# plt.show()
# In this code:
#
# ax.plot(climate_change.index, climate_change["relative_temp"]) adds the time-series data to the plot using the DataFrame index for the x values and the "relative_temp" column for the y values.
# ax.set_xlabel('Time') sets the label for the x-axis.
# ax.set_ylabel('Relative temperature (Celsius)') sets the label for the y-axis.
# plt.show() displays the figure.
# '''Using a time index to zoom in
# When a time-series is represented with a time index, we can use this index for the x-axis when plotting. We can also select a range of dates to zoom in on a particular period within the time-series using pandas' indexing facilities. In this exercise, you will select a portion of a time-series dataset and you will plot that period.
#
# The data to use is stored in a DataFrame called climate_change, which has a time-index with dates of measurements and two data columns: "co2" and "relative_temp".
#
# Instructions
# 100 XP
# Use plt.subplots to create a Figure with one Axes called fig and ax, respectively.
# Create a variable called seventies that includes all the data between "1970-01-01" and "1979-12-31".
# Add the data from seventies to the plot: use the DataFrame index for the x value and the "co2" column for the y values.'''
#
#
#
# import matplotlib.pyplot as plt
#
# # Use plt.subplots to create fig and ax
# ____
#
# # Create variable seventies with data from "1970-01-01" to "1979-12-31"
# seventies = climate_change[____]
#
# # Add the time-series for "co2" data from seventies to the plot
# ____(____, ____["co2"])
#
# # Show the figure
# ____
# ChatGPT
# Here's how you can create a plot that zooms in on the 1970s and displays the CO2 data:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Use plt.subplots to create fig and ax
# fig, ax = plt.subplots()
#
# # Create variable seventies with data from "1970-01-01" to "1979-12-31"
# seventies = climate_change["1970-01-01":"1979-12-31"]
#
# # Add the time-series for "co2" data from seventies to the plot
# ax.plot(seventies.index, seventies["co2"])
#
# # Show the figure
# plt.show()
# In this code:
#
# fig, ax = plt.subplots() creates a figure and a single axes.
# seventies = climate_change["1970-01-01":"1979-12-31"] selects the data between January 1, 1970, and December 31, 1979.
# ax.plot(seventies.index, seventies["co2"]) adds the CO2 data from the 1970s to the plot using the DataFrame index for the x values and the "co2" column for the y values.
# plt.show() displays the figure.
# '''Plotting two variables
# If you want to plot two time-series variables that were recorded at the same times, you can add both of them to the same subplot.
#
# If the variables have very different scales, you'll want to make sure that you plot them in different twin Axes objects. These objects can share one axis (for example, the time, or x-axis) while not sharing the other (the y-axis).
#
# To create a twin Axes object that shares the x-axis, we use the twinx method.
#
# In this exercise, you'll have access to a DataFrame that has the climate_change data loaded into it. This DataFrame was loaded with the "date" column set as a DateTimeIndex, and it has a column called "co2" with carbon dioxide measurements and a column called "relative_temp" with temperature measurements.
#
# Instructions
# 100 XP
# Use plt.subplots to create a Figure and Axes objects called fig and ax, respectively.
# Plot the carbon dioxide variable in blue using the Axes plot method.
# Use the Axes twinx method to create a twin Axes that shares the x-axis.
# Plot the relative temperature variable in red on the twin Axes using its plot method.'''
#
#
# import matplotlib.pyplot as plt
#
# # Initalize a Figure and Axes
# ____
#
# # Plot the CO2 variable in blue
# ax.plot(____, ____, color=____)
#
# # Create a twin Axes that shares the x-axis
# ax2 = ____
#
# # Plot the relative temperature in red
# ____.plot(____, ____, color=____)
#
# plt.show()
# ChatGPT
# Here's how you can plot two time-series variables on the same subplot using twin Axes objects:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Initialize a Figure and Axes
# fig, ax = plt.subplots()
#
# # Plot the CO2 variable in blue
# ax.plot(climate_change.index, climate_change["co2"], color='blue')
#
# # Create a twin Axes that shares the x-axis
# ax2 = ax.twinx()
#
# # Plot the relative temperature in red
# ax2.plot(climate_change.index, climate_change["relative_temp"], color='red')
#
# plt.show()
# In this code:
#
# fig, ax = plt.subplots() initializes a figure and a single axes.
# ax.plot(climate_change.index, climate_change["co2"], color='blue') plots the CO2 data in blue.
# ax.twinx() creates a twin axes that shares the x-axis with the original axes.
# ax2.plot(climate_change.index, climate_change["relative_temp"], color='red') plots the relative temperature data in red on the twin axes.
# plt.show() displays the figure.
# '''Defining a function that plots time-series data
# Once you realize that a particular section of code that you have written is useful, it is a good idea to define a function that saves that section of code for you, rather than copying it to other parts of your program where you would like to use this code.
#
# Here, we will define a function that takes inputs such as a time variable and some other variable and plots them as x and y inputs. Then, it sets the labels on the x- and y-axis and sets the colors of the y-axis label, the y-axis ticks and the tick labels.
#
# Instructions
# 100 XP
# Define a function called plot_timeseries that takes as input an Axes object (axes), data (x,y), a string with the name of a color and strings for x- and y-axis labels.
# Plot y as a function of in the color provided as the input color.
# Set the x- and y-axis labels using the provided input xlabel and ylabel, setting the y-axis label color using color.
# Set the y-axis tick parameters using the tick_params method of the Axes object, setting the colors key-word to color.'''
#
#
# # Define a function called plot_timeseries
# def ____(axes, x, y, color, xlabel, ylabel):
#
#   # Plot the inputs x,y in the provided color
#   axes.____(____, ____, color=____)
#
#   # Set the x-axis label
#   ____.____(____)
#
#   # Set the y-axis label
#   ____.____(____, color=____)
#
#   # Set the colors tick params for y-axis
#   ____.____('y', colors=____)
# ChatGPT
# Here's how you can define the plot_timeseries function to plot time-series data and set the axis labels and tick parameters:
#
# python
# Copy code
# # Define a function called plot_timeseries
# def plot_timeseries(axes, x, y, color, xlabel, ylabel):
#     # Plot the inputs x, y in the provided color
#     axes.plot(x, y, color=color)
#
#     # Set the x-axis label
#     axes.set_xlabel(xlabel)
#
#     # Set the y-axis label
#     axes.set_ylabel(ylabel, color=color)
#
#     # Set the y-axis tick parameters
#     axes.tick_params('y', colors=color)
# In this function:
#
# axes.plot(x, y, color=color) plots the x and y data on the provided axes using the specified color.
# axes.set_xlabel(xlabel) sets the label for the x-axis.
# axes.set_ylabel(ylabel, color=color) sets the label for the y-axis and colors it with the specified color.
# axes.tick_params('y', colors=color) sets the tick parameters for the y-axis, coloring the ticks and tick labels with the specified color.
# '''Using a plotting function
# Defining functions allows us to reuse the same code without having to repeat all of it. Programmers sometimes say "Don't repeat yourself".
#
# In the previous exercise, you defined a function called plot_timeseries:
#
# plot_timeseries(axes, x, y, color, xlabel, ylabel)
# that takes an Axes object (as the argument axes), time-series data (as x and y arguments) the name of a color (as a string, provided as the color argument) and x-axis and y-axis labels (as xlabel and ylabel arguments). In this exercise, the function plot_timeseries is already defined and provided to you.
#
# Use this function to plot the climate_change time-series data, provided as a pandas DataFrame object that has a DateTimeIndex with the dates of the measurements and co2 and relative_temp columns.
#
# Instructions
# 100 XP
# In the provided ax object, use the function plot_timeseries to plot the "co2" column in blue, with the x-axis label "Time (years)" and y-axis label "CO2 levels".
# Use the ax.twinx method to add an Axes object to the figure that shares the x-axis with ax.
# Use the function plot_timeseries to add the data in the "relative_temp" column in red to the twin Axes object, with the x-axis label "Time (years)" and y-axis label "Relative temperature (Celsius)".''''
#
#
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# ____(____, ____, ____, "blue", ____, ____)
#
# # Create a twin Axes object that shares the x-axis
# ax2 = ____
#
# # Plot the relative temperature data in red
# ____(____, ____, ____, "red", ____, ____)
#
# plt.show()
# ChatGPT
# Here's how you can use the plot_timeseries function to plot the climate_change data for CO2 levels and relative temperature:
#
# python
# Copy code
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# plot_timeseries(ax, climate_change.index, climate_change["co2"], "blue", "Time (years)", "CO2 levels")
#
# # Create a twin Axes object that shares the x-axis
# ax2 = ax.twinx()
#
# # Plot the relative temperature data in red
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], "red", "Time (years)", "Relative temperature (Celsius)")
#
# plt.show()
# In this code:
#
# plot_timeseries(ax, climate_change.index, climate_change["co2"], "blue", "Time (years)", "CO2 levels") plots the CO2 levels on the primary axes in blue.
# ax.twinx() creates a twin axes that shares the x-axis with the original axes.
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], "red", "Time (years)", "Relative temperature (Celsius)") plots the relative temperature data on the twin axes in red.
# plt.show() displays the figure.
# '''Annotating a plot of time-series data
# Annotating a plot allows us to highlight interesting information in the plot. For example, in describing the climate change dataset, we might want to point to the date at which the relative temperature first exceeded 1 degree Celsius.
#
# For this, we will use the annotate method of the Axes object. In this exercise, you will have the DataFrame called climate_change loaded into memory. Using the Axes methods, plot only the relative temperature column as a function of dates, and annotate the data.
#
# Instructions
# 100 XP
# Use the ax.plot method to plot the DataFrame index against the relative_temp column.
# Use the annotate method to add the text '>1 degree' in the location (pd.Timestamp('2015-10-06'), 1).'''
#
#
#
# fig, ax = plt.subplots()
#
# # Plot the relative temperature data
# ____
#
# # Annotate the date at which temperatures exceeded 1 degree
# ax.____(____, ____)
#
# plt.show()
# ChatGPT
# Here's how you can annotate a plot of the relative_temp column in the climate_change DataFrame to highlight the date at which the relative temperature first exceeded 1 degree Celsius:
#
# python
# Copy code
# import pandas as pd
#
# fig, ax = plt.subplots()
#
# # Plot the relative temperature data
# ax.plot(climate_change.index, climate_change["relative_temp"])
#
# # Annotate the date at which temperatures exceeded 1 degree
# ax.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), 1.5),
#             arrowprops=dict(facecolor='black', shrink=0.05))
#
# plt.show()
# In this code:
#
# ax.plot(climate_change.index, climate_change["relative_temp"]) plots the relative temperature data.
# ax.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), 1.5), arrowprops=dict(facecolor='black', shrink=0.05)) adds the annotation ">1 degree" at the specified location with an arrow pointing to it.
# '''Plotting time-series: putting it all together
# In this exercise, you will plot two time-series with different scales on the same Axes, and annotate the data from one of these series.
#
# The CO2/temperatures data is provided as a DataFrame called climate_change. You should also use the function that we have defined before, called plot_timeseries, which takes an Axes object (as the axes argument) plots a time-series (provided as x and y arguments), sets the labels for the x-axis and y-axis and sets the color for the data, and for the y tick/axis labels:
#
# plot_timeseries(axes, x, y, color, xlabel, ylabel)
# Then, you will annotate with text an important time-point in the data: on 2015-10-06, when the temperature first rose to above 1 degree over the average.
#
# Instructions
# 100 XP
# Use the plot_timeseries function to plot CO2 levels against time. Set xlabel to "Time (years)" ylabel to "CO2 levels" and color to 'blue'.
# Create ax2, as a twin of the first Axes.
# In ax2, plot temperature against time, setting the color ylabel to "Relative temp (Celsius)" and color to 'red'.
# Annotate the data using the ax2.annotate method. Place the text ">1 degree" in x=pd.Timestamp('2008-10-06'), y=-0.2 pointing with a gray thin arrow to x=pd.Timestamp('2015-10-06'), y = 1.'''
#
#
#
#
#
#
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# plot_timeseries(____, ____, ____, 'blue', ____, ____)
#
# # Create an Axes object that shares the x-axis
# ax2 = ____
#
# # Plot the relative temperature data in red
# plot_timeseries(____, ____, ____, 'red', ____, ____)
#
# # Annotate point with relative temperature >1 degree
# ax2.____(">1 degree", ____, ____, ____)
#
# plt.show()
# ChatGPT
# Here's how you can plot the CO2 levels and relative temperature time-series on the same plot with different y-axes and annotate the point where the temperature first exceeded 1 degree Celsius:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Function to plot time-series data
# def plot_timeseries(axes, x, y, color, xlabel, ylabel):
#     axes.plot(x, y, color=color)
#     axes.set_xlabel(xlabel)
#     axes.set_ylabel(ylabel, color=color)
#     axes.tick_params('y', colors=color)
#
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', 'Time (years)', 'CO2 levels')
#
# # Create an Axes object that shares the x-axis
# ax2 = ax.twinx()
#
# # Plot the relative temperature data in red
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], 'red', 'Time (years)', 'Relative temp (Celsius)')
#
# # Annotate point with relative temperature >1 degree
# ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), -0.2),
#              arrowprops=dict(facecolor='gray', shrink=0.05))
#
# plt.show()
# In this code:
#
# plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', 'Time (years)', 'CO2 levels') plots the CO2 levels with the color blue and appropriate labels.
# ax2 = ax.twinx() creates a second y-axis that shares the same x-axis.
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], 'red', 'Time (years)', 'Relative temp (Celsius)') plots the relative temperature data on the second y-axis with the color red and appropriate labels.
# ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), -0.2), arrowprops=dict(facecolor='gray', shrink=0.05)) adds an annotation with an arrow pointing to the date when the temperature first exceeded 1 degree Celsius.
# Incorrect submission
# Check your call of ax2.annotate(). Did you correctly specify the argument arrowprops? Expected {'arrowstyle': '->', 'color': 'gray'}, but got {'facecolor': 'gray', 'shrink': 0.05}.
# ChatGPT
# It looks like I specified the wrong arrowprops in the annotate method. Let's correct it with the expected arrowstyle and color.
#
# Here's the corrected code:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Function to plot time-series data
# def plot_timeseries(axes, x, y, color, xlabel, ylabel):
#     axes.plot(x, y, color=color)
#     axes.set_xlabel(xlabel)
#     axes.set_ylabel(ylabel, color=color)
#     axes.tick_params('y', colors=color)
#
# fig, ax = plt.subplots()
#
# # Plot the CO2 levels time-series in blue
# plot_timeseries(ax, climate_change.index, climate_change["co2"], 'blue', 'Time (years)', 'CO2 levels')
#
# # Create an Axes object that shares the x-axis
# ax2 = ax.twinx()
#
# # Plot the relative temperature data in red
# plot_timeseries(ax2, climate_change.index, climate_change["relative_temp"], 'red', 'Time (years)', 'Relative temp (Celsius)')
#
# # Annotate point with relative temperature >1 degree
# ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06'), 1), xytext=(pd.Timestamp('2008-10-06'), -0.2),
#              arrowprops=dict(arrowstyle='->', color='gray'))
#
# plt.show()
# In this version:
#
# The arrowprops argument in the annotate method now uses arrowstyle='->' and color='gray' to match the expected specification.
# '''Bar chart
# Bar charts visualize data that is organized according to categories as a series of bars, where the height of each bar represents the values of the data in this category.
#
# For example, in this exercise, you will visualize the number of gold medals won by each country in the provided medals DataFrame. The DataFrame contains the countries as the index, and a column called "Gold" that contains the number of gold medals won by each country, according to their rows.
#
# Instructions
# 100 XP
# Call the ax.bar method to plot the "Gold" column as a function of the country.
# Use the ax.set_xticklabels to set the x-axis tick labels to be the country names.
# In the call to ax.set_xticklabels rotate the x-axis tick labels by 90 degrees by using the rotation key-word argument.
# Set the y-axis label to "Number of medals".'''
#
#
# fig, ax = plt.subplots()
#
# # Plot a bar-chart of gold medals as a function of country
# ____
#
# # Set the x-axis tick labels to the country names
# ____.set_xticklabels(____, ____)
#
# # Set the y-axis label
# ____
#
# plt.show()
# ChatGPT
# Here is the corrected code to create a bar chart, set the x-axis tick labels, and rotate them by 90 degrees:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots()
#
# # Plot a bar-chart of gold medals as a function of country
# ax.bar(medals.index, medals["Gold"])
#
# # Set the x-axis tick labels to the country names and rotate them by 90 degrees
# ax.set_xticklabels(medals.index, rotation=90)
#
# # Set the y-axis label
# ax.set_ylabel("Number of medals")
#
# plt.show()
# In this code:
#
# The ax.bar method is used to plot the gold medals as a function of the country.
# The ax.set_xticklabels method is used to set the x-axis tick labels to the country names and rotate them by 90 degrees.
# The ax.set_ylabel method is used to set the y-axis label to "Number of medals".
# '''Stacked bar chart
# A stacked bar chart contains bars, where the height of each bar represents values. In addition, stacked on top of the first variable may be another variable. The additional height of this bar represents the value of this variable. And you can add more bars on top of that.
#
# In this exercise, you will have access to a DataFrame called medals that contains an index that holds the names of different countries, and three columns: "Gold", "Silver" and "Bronze". You will also have a Figure, fig, and Axes, ax, that you can add data to.
#
# You will create a stacked bar chart that shows the number of gold, silver, and bronze medals won by each country, and you will add labels and create a legend that indicates which bars represent which medals.
#
# Instructions
# 100 XP
# Call the ax.bar method to add the "Gold" medals. Call it with the label set to "Gold".
# Call the ax.bar method to stack "Silver" bars on top of that, using the bottom key-word argument so the bottom of the bars will be on top of the gold medal bars, and label to add the label "Silver".
# Use ax.bar to add "Bronze" bars on top of that, using the bottom key-word and label it as "Bronze".'''
#
# # Add bars for "Gold" with the label "Gold"
# ____(____, ____, label=____)
#
# # Stack bars for "Silver" on top with label "Silver"
# ____(____, ____, bottom=____, ____)
#
# # Stack bars for "Bronze" on top of that with label "Bronze"
# ____
#
# # Display the legend
# ax.legend()
#
# plt.show()
# ChatGPT
# Here is the complete code to create a stacked bar chart showing the number of gold, silver, and bronze medals won by each country:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Assuming medals is a DataFrame with columns "Gold", "Silver", and "Bronze"
# # and an index that holds the names of different countries
#
# fig, ax = plt.subplots()
#
# # Add bars for "Gold" with the label "Gold"
# ax.bar(medals.index, medals["Gold"], label="Gold")
#
# # Stack bars for "Silver" on top with label "Silver"
# ax.bar(medals.index, medals["Silver"], bottom=medals["Gold"], label="Silver")
#
# # Stack bars for "Bronze" on top of that with label "Bronze"
# ax.bar(medals.index, medals["Bronze"], bottom=medals["Gold"] + medals["Silver"], label="Bronze")
#
# # Display the legend
# ax.legend()
#
# plt.show()
# In this code:
#
# The ax.bar method is used to create the gold medal bars.
# The bottom keyword argument is used to stack the silver medal bars on top of the gold medal bars.
# The bottom keyword argument is again used to stack the bronze medal bars on top of the combined height of the gold and silver bars.
# The ax.legend() method is used to display the legend.
# '''Creating histograms
# Histograms show the full distribution of a variable. In this exercise, we will display the distribution of weights of medalists in gymnastics and in rowing in the 2016 Olympic games for a comparison between them.
#
# You will have two DataFrames to use. The first is called mens_rowing and includes information about the medalists in the men's rowing events. The other is called mens_gymnastics and includes information about medalists in all of the Gymnastics events.
#
# Instructions
# 100 XP
# Use the ax.hist method to add a histogram of the "Weight" column from the mens_rowing DataFrame.
# Use ax.hist to add a histogram of "Weight" for the mens_gymnastics DataFrame.
# Set the x-axis label to "Weight (kg)" and the y-axis label to "# of observations".'''
#
#
# fig, ax = plt.subplots()
# # Plot a histogram of "Weight" for mens_rowing
# ax.hist(____)
#
# # Compare to histogram of "Weight" for mens_gymnastics
# ____
#
# # Set the x-axis label to "Weight (kg)"
# ____
#
# # Set the y-axis label to "# of observations"
# ____
#
# plt.show()
# ChatGPT
# Here's the complete code to create histograms for the weights of medalists in men's rowing and gymnastics in the 2016 Olympic games:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots()
#
# # Plot a histogram of "Weight" for mens_rowing
# ax.hist(mens_rowing["Weight"], bins=15, alpha=0.7, label='Rowing')
#
# # Compare to histogram of "Weight" for mens_gymnastics
# ax.hist(mens_gymnastics["Weight"], bins=15, alpha=0.7, label='Gymnastics')
#
# # Set the x-axis label to "Weight (kg)"
# ax.set_xlabel("Weight (kg)")
#
# # Set the y-axis label to "# of observations"
# ax.set_ylabel("# of observations")
#
# # Add a legend to differentiate the histograms
# ax.legend()
#
# plt.show()
# In this code:
#
# The ax.hist method is used to create histograms for the "Weight" columns from both mens_rowing and mens_gymnastics DataFrames.
# The bins argument is used to set the number of bins in the histogram.
# The alpha argument is used to set the transparency of the bars, so both histograms can be seen when they overlap.
# The ax.set_xlabel and ax.set_ylabel methods are used to set the x-axis and y-axis labels, respectively.
# The ax.legend method is used to add a legend to the plot to differentiate between the two histograms.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Plot a histogram of "Weight" for mens_rowing using step type
ax.hist(mens_rowing["Weight"], bins=5, histtype='step', label='Rowing')

# Compare to histogram of "Weight" for mens_gymnastics using step type
ax.hist(mens_gymnastics["Weight"], bins=5, histtype='step', label='Gymnastics')

# Set the x-axis label to "Weight (kg)"
ax.set_xlabel("Weight (kg)")

# Set the y-axis label to "# of observations"
ax.set_ylabel("# of observations")

# Add the legend and show the Figure
ax.legend()

plt.show()

# %% [markdown]
# '''"Step" histogram
# Histograms allow us to see the distributions of the data in different groups in our data. In this exercise, you will select groups from the Summer 2016 Olympic Games medalist dataset to compare the height of medalist athletes in two different sports.
#
# The data is stored in a pandas DataFrame object called summer_2016_medals that has a column "Height". In addition, you are provided a pandas GroupBy object that has been grouped by the sport.
#
# In this exercise, you will visualize and label the histograms of two sports: "Gymnastics" and "Rowing" and see the marked difference between medalists in these two sports.
#
# Instructions
# 100 XP
# Use the hist method to display a histogram of the "Weight" column from the mens_rowing DataFrame, label this as "Rowing".
# Use hist to display a histogram of the "Weight" column from the mens_gymnastics DataFrame, and label this as "Gymnastics".
# For both histograms, use the histtype argument to visualize the data using the 'step' type and set the number of bins to use to 5.
# Add a legend to the figure, before it is displayed.'''
#
#
# fig, ax = plt.subplots()
#
# # Plot a histogram of "Weight" for mens_rowing
# ____
#
# # Compare to histogram of "Weight" for mens_gymnastics
# ____
#
# ax.set_xlabel("Weight (kg)")
# ax.set_ylabel("# of observations")
#
# # Add the legend and show the Figure
# ____
# plt.show()
# ChatGPT
# Here’s the code to create step histograms for the weights of medalists in rowing and gymnastics:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots()
#
# # Plot a histogram of "Weight" for mens_rowing using step type
# ax.hist(mens_rowing["Weight"], bins=5, histtype='step', label='Rowing')
#
# # Compare to histogram of "Weight" for mens_gymnastics using step type
# ax.hist(mens_gymnastics["Weight"], bins=5, histtype='step', label='Gymnastics')
#
# # Set the x-axis label to "Weight (kg)"
# ax.set_xlabel("Weight (kg)")
#
# # Set the y-axis label to "# of observations"
# ax.set_ylabel("# of observations")
#
# # Add the legend and show the Figure
# ax.legend()
#
# plt.show()
# In this code:
#
# The histtype='step' argument in ax.hist is used to create a step histogram.
# The bins=5 argument specifies the number of bins to use.
# The label argument adds a label for each histogram, which will be used in the legend.
# The ax.legend() method adds the legend to differentiate between the two histograms.

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()

# Calculate mean and standard deviation for rowing heights
mean_rowing = mens_rowing["Height"].mean()
std_rowing = mens_rowing["Height"].std()

# Add a bar for the rowing "Height" column mean with error bars
ax.bar("Rowing", mean_rowing, yerr=std_rowing, capsize=5)

# Calculate mean and standard deviation for gymnastics heights
mean_gymnastics = mens_gymnastics["Height"].mean()
std_gymnastics = mens_gymnastics["Height"].std()

# Add a bar for the gymnastics "Height" column mean with error bars
ax.bar("Gymnastics", mean_gymnastics, yerr=std_gymnastics, capsize=5)

# Label the y-axis
ax.set_ylabel("Height (cm)")

plt.show()
# That's great! These error bars can help you see that the difference in heights is rather large in terms of the standard deviation within every group.

# %% [markdown]
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots()
#
# # Add Seattle temperature data in each month with error bars
# ax.errorbar(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"],
#             yerr=seattle_weather["MLY-TAVG-STDDEV"], label='Seattle', fmt='o', color='blue')
#
# # Add Austin temperature data in each month with error bars
# ax.errorbar(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"],
#             yerr=austin_weather["MLY-TAVG-STDDEV"], label='Austin', fmt='o', color='red')
#
# # Set the y-axis label
# ax.set_ylabel("Temperature (Fahrenheit)")
#
# # Add a legend to distinguish between Seattle and Austin
# ax.legend()
#
# plt.show()

# %% [markdown]
# '''Adding error-bars to a plot
# Adding error-bars to a plot is done by using the errorbar method of the Axes object.
#
# Here, you have two DataFrames loaded: seattle_weather has data about the weather in Seattle and austin_weather has data about the weather in Austin. Each DataFrame has a column "MONTH" that has the names of the months, a column "MLY-TAVG-NORMAL" that has the average temperature in each month and a column "MLY-TAVG-STDDEV" that has the standard deviation of the temperatures across years.
#
# In the exercise, you will plot the mean temperature across months and add the standard deviation at each point as y errorbars.
#
# Instructions
# 100 XP
# Use the ax.errorbar method to add the Seattle data: the "MONTH" column as x values, the "MLY-TAVG-NORMAL" as y values and "MLY-TAVG-STDDEV" as yerr values.
# Add the Austin data: the "MONTH" column as x values, the "MLY-TAVG-NORMAL" as y values and "MLY-TAVG-STDDEV" as yerr values.
# Set the y-axis label as "Temperature (Fahrenheit)".'''
#
#
# fig, ax = plt.subplots()
#
# # Add Seattle temperature data in each month with error bars
# ax.errorbar(____, ____, ____)
#
# # Add Austin temperature data in each month with error bars
# ____
#
# # Set the y-axis label
# ____
#
# plt.show()
# ChatGPT
# Here's how you can add error bars to a plot with the Seattle and Austin weather data:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots()
#
# # Add Seattle temperature data in each month with error bars
# ax.errorbar(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"],
#             yerr=seattle_weather["MLY-TAVG-STDDEV"], label='Seattle', fmt='o', color='blue')
#
# # Add Austin temperature data in each month with error bars
# ax.errorbar(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"],
#             yerr=austin_weather["MLY-TAVG-STDDEV"], label='Austin', fmt='o', color='red')
#
# # Set the y-axis label
# ax.set_ylabel("Temperature (Fahrenheit)")
#
# # Add a legend to distinguish between Seattle and Austin
# ax.legend()
#
# plt.show()
# In this code:
#
# ax.errorbar() is used to plot the data with error bars. The MONTH column is used for the x values, MLY-TAVG-NORMAL for the y values, and MLY-TAVG-STDDEV for the y-error bars.
# fmt='o' specifies that the data points should be marked with circles.
# color='blue' and color='red' distinguish between the Seattle and Austin data points.
# ax.set_ylabel() sets the label for the y-axis.
# ax.legend() adds a legend to the plot for clarity.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Add a boxplot for the "Height" column in the DataFrames
ax.boxplot([mens_rowing["Height"], mens_gymnastics["Height"]])

# Add x-axis tick labels:
ax.set_xticklabels(["Rowing", "Gymnastics"])

# Add a y-axis label
ax.set_ylabel("Height (cm)")

plt.show()

'''very good. This provides even more information. For example, we can see how many individuals are outliers within their group. Next, let's see how we compare two variables within a single sample.'''

# %% [markdown]
# You
# Sent by you:
# '''Creating boxplots
# Boxplots provide additional information about the distribution of the data that they represent. They tell us what the median of the distribution is, what the inter-quartile range is and also what the expected range of approximately 99% of the data should be. Outliers beyond this range are particularly highlighted.
#
# In this exercise, you will use the data about medalist heights that you previously visualized as histograms, and as bar charts with error bars, and you will visualize it as boxplots.
#
# Again, you will have the mens_rowing and mens_gymnastics DataFrames available to you, and both of these DataFrames have columns called "Height" that you will compare.
#
# Instructions
# 100 XP
# Create a boxplot that contains the "Height" column for mens_rowing on the left and mens_gymnastics on the right.
# Add x-axis tick labels: "Rowing" and "Gymnastics".
# Add a y-axis label: "Height (cm)".'''
#
# fig, ax = plt.subplots()
#
# # Add a boxplot for the "Height" column in the DataFrames
# ____
#
# # Add x-axis tick labels:
# ____
#
# # Add a y-axis label
# ____
#
# plt.show()
# Copilot
# Sent by Copilot:
# Here’s how you can complete the code to create the boxplots for the “Height” columns in the mens_rowing and mens_gymnastics DataFrames:
#
# Python
#
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots()
#
# # Add a boxplot for the "Height" column in the DataFrames
# ax.boxplot([mens_rowing["Height"], mens_gymnastics["Height"]])
#
# # Add x-axis tick labels:
# ax.set_xticklabels(["Rowing", "Gymnastics"])
#
# # Add a y-axis label
# ax.set_ylabel("Height (cm)")
#
# plt.show()
# AI-generated code. Review and use carefully. More info on FAQ.
# This code will generate a boxplot with the heights of the men’s rowing team on the left and the men’s gymnastics team on the right. The x-axis will be labeled “Rowing” and “Gymnastics”, and the y-axis will be labeled “Height (cm)”. Let me know if you need any further assistance!

# %%
import matplotlib.pyplot as plt

# Assuming climate_change DataFrame is already loaded

fig, ax = plt.subplots()

# Add data: "co2" on x-axis, "relative_temp" on y-axis
ax.scatter(climate_change['co2'], climate_change['relative_temp'])

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("CO2 (ppm)")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Relative temperature (C)")

plt.show()

# %% [markdown]
# Simple scatter plot
# Scatter are a bi-variate visualization technique. They plot each record in the data as a point. The location of each point is determined by the value of two variables: the first variable determines the distance along the x-axis and the second variable determines the height along the y-axis.
# ChatGPT
# To create a simple scatter plot using matplotlib, follow these steps:
#
# Import the necessary libraries:
# Ensure you have matplotlib.pyplot and pandas imported. If you're working with data in a DataFrame, you'll also need pandas.
#
# Prepare the data:
# You need two columns of data: one for the x-axis and one for the y-axis.
#
# Plot the scatter plot:
# Use the scatter method from matplotlib to create the plot.
#
# Here's an example of how to create a simple scatter plot:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Example data
# data = {
#     'x': [1, 2, 3, 4, 5],
#     'y': [2, 3, 5, 7, 11]
# }
# df = pd.DataFrame(data)
#
# # Create a scatter plot
# plt.figure(figsize=(8, 6))
# plt.scatter(df['x'], df['y'], color='blue', label='Data Points')
#
# # Add titles and labels
# plt.title('Simple Scatter Plot')
# plt.xlabel('X-axis Label')
# plt.ylabel('Y-axis Label')
# plt.legend()
#
# # Show the plot
# plt.show()
# Explanation:
# plt.scatter(df['x'], df['y'], color='blue', label='Data Points'): Plots each record as a point on the scatter plot, where df['x'] represents the x-axis values and df['y'] represents the y-axis values.
# plt.title('Simple Scatter Plot'): Sets the title of the plot.
# plt.xlabel('X-axis Label'): Sets the label for the x-axis.
# plt.ylabel('Y-axis Label'): Sets the label for the y-axis.
# plt.legend(): Adds a legend to the plot.
# This example demonstrates the basics of creating a scatter plot. You can customize the appearance of the points and the plot further using additional parameters and styling options available in matplotlib.
#
# '''Simple scatter plot
# Scatter are a bi-variate visualization technique. They plot each record in the data as a point. The location of each point is determined by the value of two variables: the first variable determines the distance along the x-axis and the second variable determines the height along the y-axis.
#
# In this exercise, you will create a scatter plot of the climate_change data. This DataFrame, which is already loaded, has a column "co2" that indicates the measurements of carbon dioxide every month and another column, "relative_temp" that indicates the temperature measured at the same time.
#
# Instructions
# 100 XP
# Using the ax.scatter method, add the data to the plot: "co2" on the x-axis and "relative_temp" on the y-axis.
# Set the x-axis label to "CO2 (ppm)".
# Set the y-axis label to "Relative temperature (C)".'''
#
# fig, ax = plt.subplots()
#
# # Add data: "co2" on x-axis, "relative_temp" on y-axis
# ____
#
# # Set the x-axis label to "CO2 (ppm)"
# ____
#
# # Set the y-axis label to "Relative temperature (C)"
# ____
#
# plt.show()
# ChatGPT
# Here's how you can create the scatter plot using the climate_change DataFrame:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Assuming climate_change DataFrame is already loaded
#
# fig, ax = plt.subplots()
#
# # Add data: "co2" on x-axis, "relative_temp" on y-axis
# ax.scatter(climate_change['co2'], climate_change['relative_temp'])
#
# # Set the x-axis label to "CO2 (ppm)"
# ax.set_xlabel("CO2 (ppm)")
#
# # Set the y-axis label to "Relative temperature (C)"
# ax.set_ylabel("Relative temperature (C)")
#
# plt.show()
# Explanation:
# ax.scatter(climate_change['co2'], climate_change['relative_temp']): Creates a scatter plot with "co2" on the x-axis and "relative_temp" on the y-axis.
# ax.set_xlabel("CO2 (ppm)"): Sets the label for the x-axis.
# ax.set_ylabel("Relative temperature (C)"): Sets the label for the y-axis.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Add data: "co2" on x-axis, "relative_temp" on y-axis, index as color
scatter = ax.scatter(climate_change['co2'], climate_change['relative_temp'], c=climate_change.index, cmap='cividis')

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("CO2 (ppm)")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Relative temperature (C)")

plt.colorbar(scatter, ax=ax, label='Time')  # Add colorbar to show time encoding

plt.show()

# %% [markdown]
# Encoding time by color
# The screen only has two dimensions, but we can encode another dimension in the scatter plot using color. Here, we will visualize the climate_change dataset, plotting a scatter plot of the "co2" column, on the x-axis, against the "relative_temp" column, on the y-axis. We will encode time using the color dimension, with earlier times appearing as darker shades of blue and later times appearing as brighter shades of yellow.
# ChatGPT
# To encode time by color in a scatter plot, you'll need to use a colormap to represent different times. Here’s how you can do it:
#
# Normalize the time data: To map the time data to colors, you first need to normalize it to a range between 0 and 1.
# Create a colormap: Use a colormap to convert the normalized time data into colors.
# Plot the scatter plot: Use the colors in the scatter plot to represent time.
# Here's how you can achieve this with the climate_change DataFrame:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import matplotlib.colors as mcolors
# import numpy as np
#
# # Assuming climate_change DataFrame is already loaded
# # Normalize the time data
# norm = plt.Normalize(climate_change.index.min().toordinal(), climate_change.index.max().toordinal())
# cmap = plt.get_cmap('cividis')  # You can choose a different colormap if you prefer
#
# # Convert dates to ordinal numbers for normalization
# colors = cmap(norm(climate_change.index.toordinal()))
#
# fig, ax = plt.subplots()
#
# # Add data: "co2" on x-axis, "relative_temp" on y-axis with color encoding for time
# scatter = ax.scatter(climate_change['co2'], climate_change['relative_temp'], c=colors, edgecolor='k')
#
# # Create a colorbar to show the time encoding
# cbar = plt.colorbar(mcolors.ScalarMappable(norm=norm, cmap=cmap), ax=ax)
# cbar.set_label('Time')
#
# # Set the x-axis label to "CO2 (ppm)"
# ax.set_xlabel("CO2 (ppm)")
#
# # Set the y-axis label to "Relative temperature (C)"
# ax.set_ylabel("Relative temperature (C)")
#
# plt.show()
# Explanation:
# plt.Normalize() normalizes the time data (which is in ordinal format) to a range [0, 1].
# cmap = plt.get_cmap('cividis') sets the colormap. You can choose other colormaps like 'viridis', 'plasma', etc.
# colors = cmap(norm(climate_change.index.toordinal())) generates color values from the colormap based on the normalized time data.
# ax.scatter(...) plots the scatter plot with colors representing time.
# plt.colorbar(...) adds a colorbar to the plot to show the time encoding.
# '''Encoding time by color
# The screen only has two dimensions, but we can encode another dimension in the scatter plot using color. Here, we will visualize the climate_change dataset, plotting a scatter plot of the "co2" column, on the x-axis, against the "relative_temp" column, on the y-axis. We will encode time using the color dimension, with earlier times appearing as darker shades of blue and later times appearing as brighter shades of yellow.
#
# Instructions
# 100 XP
# Using the ax.scatter method add a scatter plot of the "co2" column (x-axis) against the "relative_temp" column.
# Use the c key-word argument to pass in the index of the DataFrame as input to color each point according to its date.
# Set the x-axis label to "CO2 (ppm)" and the y-axis label to "Relative temperature (C)".'''
#
# fig, ax = plt.subplots()
#
# # Add data: "co2", "relative_temp" as x-y, index as color
# ____
#
# # Set the x-axis label to "CO2 (ppm)"
# ____
#
# # Set the y-axis label to "Relative temperature (C)"
# ____
#
# plt.show()
# ChatGPT
# To encode time by color in your scatter plot using the climate_change dataset, follow these steps:
#
# Plot the data: Use ax.scatter to create the scatter plot, with c set to the DataFrame index to encode time.
# Set labels: Label the x-axis and y-axis appropriately.
# Here’s how you can implement it:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# fig, ax = plt.subplots()
#
# # Add data: "co2" on x-axis, "relative_temp" on y-axis, index as color
# scatter = ax.scatter(climate_change['co2'], climate_change['relative_temp'], c=climate_change.index, cmap='cividis')
#
# # Set the x-axis label to "CO2 (ppm)"
# ax.set_xlabel("CO2 (ppm)")
#
# # Set the y-axis label to "Relative temperature (C)"
# ax.set_ylabel("Relative temperature (C)")
#
# plt.colorbar(scatter, ax=ax, label='Time')  # Add colorbar to show time encoding
#
# plt.show()
# Explanation:
# c=climate_change.index uses the index of the DataFrame to color each point according to its date.
# cmap='cividis' specifies the colormap, which ranges from darker shades to lighter shades to represent time.
# plt.colorbar(scatter, ax=ax, label='Time') adds a colorbar to the plot to indicate how the colors correspond to different times.

# %% [markdown]
# Selecting a style for printing
# You are creating a figure that will be included in a leaflet printed on a black-and-white printer. What style should you choose for your figures?
#
# In the console, we have loaded the medals dataset. Before initializing Axes and Figure objects and plotting them, you can try setting a style to use.
#
# Instructions
# 50 XP
# Possible answers
#
#
# 'seaborn-colorblind'
#
# 'grayscale'
#
# 'tableau-colorblind10'
#
# 'bmh'
# ChatGPT
# For printing in black-and-white, the best style to choose is 'grayscale'. This style ensures that all plot elements are visible and distinguishable in grayscale, which is ideal for black-and-white printing.
#
# Here’s how you would set the style:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# plt.style.use('grayscale')
# This will make sure that your figures are suitable for black-and-white printing.
#
# Correct! This style would make sure that your figures appear the same on your screen and on the page.

# %%
import matplotlib.pyplot as plt

# Use the "ggplot" style
plt.style.use('ggplot')

# Create new Figure and Axes
fig, ax = plt.subplots()

# Plot the Seattle weather data
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])

plt.show()

# %% [markdown]
# '''Switching between styles
# Selecting a style to use affects all of the visualizations that are created after this style is selected.
#
# Here, you will practice plotting data in two different styles. The data you will use is the same weather data we used in the first lesson: you will have available to you the DataFrame seattle_weather and the DataFrame austin_weather, both with records of the average temperature in every month.
#
# Instructions 1/2
# 50 XP
# 1
# Select the 'ggplot' style, create a new Figure called fig, and a new Axes object called ax with plt.subplots'''
#
# # Use the "ggplot" style and create new Figure/Axes
# ____
# ____
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
# plt.show()
# ChatGPT
# To switch to the 'ggplot' style and create a new Figure and Axes object, you can follow these steps:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Use the "ggplot" style
# plt.style.use('ggplot')
#
# # Create new Figure and Axes
# fig, ax = plt.subplots()
#
# # Plot the Seattle weather data
# ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
#
# plt.show()
# This will apply the 'ggplot' style to the plot and create a visualization of the Seattle weather data.

# %%
import matplotlib.pyplot as plt

# Use the "Solarize_Light2" style
plt.style.use('Solarize_Light2')

# Create new Figure and Axes
fig, ax = plt.subplots()

# Plot the Austin weather data
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])

plt.show()

# %% [markdown]
# '''Switching between styles
# Selecting a style to use affects all of the visualizations that are created after this style is selected.
#
# Here, you will practice plotting data in two different styles. The data you will use is the same weather data we used in the first lesson: you will have available to you the DataFrame seattle_weather and the DataFrame austin_weather, both with records of the average temperature in every month.
#
# Instructions 2/2
# 50 XP
# Select the 'ggplot' style, create a new Figure called fig, and a new Axes object called ax with plt.subplots.
#
# 2
# Select the 'Solarize_Light2' style, create a new Figure called fig, and a new Axes object called ax with plt.subplots.'''
#
# # Use the "Solarize_Light2" style and create new Figure/Axes
# ____
# ____
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
# plt.show()
# ChatGPT
# To switch to the 'Solarize_Light2' style and create a new Figure and Axes object, you can use the following code:
#
# python
# Copy code
# import matplotlib.pyplot as plt
#
# # Use the "Solarize_Light2" style
# plt.style.use('Solarize_Light2')
#
# # Create new Figure and Axes
# fig, ax = plt.subplots()
#
# # Plot the Austin weather data
# ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
#
# plt.show()
# This will apply the 'Solarize_Light2' style to the plot and create a visualization of the Austin weather data.
#
# Great! As you've seen, the style will only apply to a figure that is created after the style to use is selected.

# %%
plt.show()

# Save the figure with default resolution
fig.savefig('my_figure.png')

# Save the figure as a PNG file with 300 dpi
fig.savefig('my_figure_300dpi.png', dpi=300)


'''Nice! You are ready to share your visualizations in all kinds of formats! Don't forget that you can also use other formats. For example, JPG can be used to save images with lossy compression.'''

# %% [markdown]
# '''Saving a file several times
# If you want to share your visualizations with others, you will need to save them into files. Matplotlib provides as way to do that, through the savefig method of the Figure object. In this exercise, you will save a figure several times. Each time setting the parameters to something slightly different. We have provided and already created Figure object.'''
#
# # Show the figure
# ____
# ChatGPT
# To save a figure several times with different parameters, you can use the savefig method of the Figure object. Here’s how you can save the figure with different settings and then show it:
#
# python
# Copy code
# # Show the figure
# fig.show()
#
# # Save the figure with different settings
# fig.savefig('figure1.png', dpi=300, bbox_inches='tight')
# fig.savefig('figure2.pdf', dpi=150, bbox_inches='tight')
# fig.savefig('figure3.png', dpi=100, bbox_inches='tight')
# In this example:
#
# dpi specifies the resolution of the saved image (dots per inch).
# bbox_inches='tight' adjusts the bounding box to include all the content.
# Make sure to adjust the file names and parameters according to your specific needs.
#
# Incorrect submission
# Did you call plt.show()?
# ChatGPT
# If you need to show the figure using plt.show() and then save it, you can use the following approach:
#
# python
# Copy code
# # Show the figure
# plt.show()
#
# # Save the figure with different settings
# fig.savefig('figure1.png', dpi=300, bbox_inches='tight')
# fig.savefig('figure2.pdf', dpi=150, bbox_inches='tight')
# fig.savefig('figure3.png', dpi=100, bbox_inches='tight')
# Make sure you call plt.show() to display the figure before saving it.
#
# Save the figure into the file my_figure.png, using the default resolution.
#
#
# ChatGPT
# To save the figure into a file named my_figure.png using the default resolution, you can use the following code:
#
# python
# Copy code
# # Save the figure with default resolution
# fig.savefig('my_figure.png')
# # Save the figure into the file my_figure_300dpi.png and set the resolution to 300 dpi.
#
# # Save as a PNG file with 300 dpi
# ____
# ChatGPT
# To save the figure into a file named my_figure_300dpi.png with a resolution of 300 dpi, use the following code:
#
# python
# Copy code
# # Save the figure as a PNG file with 300 dpi
# fig.savefig('my_figure_300dpi.png', dpi=300)
# '''Save a figure with different sizes
# Before saving your visualization, you might want to also set the size that the figure will have on the page. To do so, you can use the Figure object's set_size_inches method. This method takes a sequence of two values. The first sets the width and the second sets the height of the figure.
#
# Here, you will again have a Figure object called fig already provided (you can run plt.show if you want to see its contents). Use the Figure methods set_size_inches and savefig to change its size and save two different versions of this figure.
#
# Instructions 1/2
# 50 XP
# 1
# Set the figure size as width of 3 inches and height of 5 inches and save it as 'figure_3_5.png' with default resolution.'''
#
#
# # Set figure dimensions and save as a PNG
# ____
# ____
# ChatGPT
# To set the figure size to a width of 3 inches and a height of 5 inches, and save it as 'figure_3_5.png' with the default resolution, use the following code:
#
# python
# Copy code
# # Set the figure size
# fig.set_size_inches(3, 5)
#
# # Save the figure as a PNG file with the default resolution
# fig.savefig('figure_3_5.png')
# '''Save a figure with different sizes
# Before saving your visualization, you might want to also set the size that the figure will have on the page. To do so, you can use the Figure object's set_size_inches method. This method takes a sequence of two values. The first sets the width and the second sets the height of the figure.
#
# Here, you will again have a Figure object called fig already provided (you can run plt.show if you want to see its contents). Use the Figure methods set_size_inches and savefig to change its size and save two different versions of this figure.
#
# Instructions 1/2
# 50 XP
# 1
# Set the figure size as width of 3 inches and height of 5 inches and save it as 'figure_3_5.png' with default resolution.'''
#
#
# # Set figure dimensions and save as a PNG
# ____
# ____
# ChatGPT
# To set the figure size to a width of 3 inches and a height of 5 inches, and save it as 'figure_3_5.png' with the default resolution, use the following code:
#
# python
# Copy code
# # Set the figure size
# fig.set_size_inches(3, 5)
#
# # Save the figure as a PNG file with the default resolution
# fig.savefig('figure_3_5.png')
# Incorrect submission
# Check your call of fig.set_size_inches(). Did you correctly specify the argument w? Expected [3, 5], but got 3.
# ChatGPT
# It looks like the set_size_inches method expects a list or tuple of two values for width and height. Here's the corrected code:
#
# python
# Copy code
# # Set the figure size to width of 3 inches and height of 5 inches
# fig.set_size_inches([3, 5])
#
# # Save the figure as a PNG file with the default resolution
# fig.savefig('figure_3_5.png')
# # Set the figure size to width of 5 inches and height of 3 inches and save it as 'figure_5_3.png' with default settings.
#
# # Set figure dimensions and save as a PNG
# ____
# ____
# ChatGPT
# Here's how you can set the figure size to a width of 5 inches and a height of 3 inches, and save it as 'figure_5_3.png':
#
# python
# Copy code
# # Set the figure size to width of 5 inches and height of 3 inches
# fig.set_size_inches([5, 3])
#
# # Save the figure as a PNG file with the default settings
# fig.savefig('figure_5_3.png')

# %%
# Extract the "Sport" column
sports_column = summer_2016_medals['Sport']

# Find the unique values of the "Sport" column
sports = sports_column.unique()

# Print out the unique sports values
print(sports)

# %% [markdown]
# Unique values of a column
# One of the main strengths of Matplotlib is that it can be automated to adapt to the data that it receives as input. For example, if you receive data that has an unknown number of categories, you can still create a bar plot that has bars for each category.
# ChatGPT
# To create a bar plot that adapts to an unknown number of categories, you need to first determine the unique categories in your data. Here’s a step-by-step approach for handling this with Matplotlib and Pandas:
#
# Identify Unique Categories: Use Pandas to get the unique values from the relevant column.
#
# Count Occurrences: Count the number of occurrences for each unique value if necessary.
#
# Plot with Matplotlib: Create a bar plot with Matplotlib, using the unique categories as the x-axis and their counts or values as the y-axis.
#
# Here’s an example workflow:
#
# Example Workflow
# Assuming you have a DataFrame df with a column named 'category':
#
# python
# Copy code
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Sample DataFrame
# data = {
#     'category': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'C', 'B']
# }
# df = pd.DataFrame(data)
#
# # 1. Get unique categories and their counts
# category_counts = df['category'].value_counts()
#
# # 2. Create a bar plot
# fig, ax = plt.subplots()
# ax.bar(category_counts.index, category_counts.values)
#
# # 3. Set labels and title
# ax.set_xlabel('Category')
# ax.set_ylabel('Count')
# ax.set_title('Count of Each Category')
#
# plt.show()
# Explanation
# df['category'].value_counts(): This computes the count of unique values in the 'category' column.
# ax.bar(): Creates a bar plot where the x-axis represents unique categories and the y-axis represents the count of each category.
# plt.show(): Displays the plot.
# This approach is flexible and will work regardless of how many unique categories are present in your data.
#
# Unique values of a column
# One of the main strengths of Matplotlib is that it can be automated to adapt to the data that it receives as input. For example, if you receive data that has an unknown number of categories, you can still create a bar plot that has bars for each category.
#
# In this exercise and the next, you will be visualizing the weight of athletes in the 2016 summer Olympic Games again, from a dataset that has some unknown number of branches of sports in it. This will be loaded into memory as a pandas DataFrame object called summer_2016_medals, which has a column called "Sport" that tells you to which branch of sport each row corresponds. There is also a "Weight" column that tells you the weight of each athlete.
#
# In this exercise, we will extract the unique values of the "Sport" column
#
# Instructions
# 100 XP
# Create a variable called sports_column that holds the data from the "Sport" column of the DataFrame object.
# Use the unique method of this variable to find all the unique different sports that are present in this data, and assign these values into a new variable called sports.
# Print the sports variable to the console.
# ChatGPT
# Here’s how you can extract and print the unique values of the "Sport" column from the summer_2016_medals DataFrame:
#
# python
# Copy code
# import pandas as pd
#
# # Assuming the DataFrame 'summer_2016_medals' is already loaded
# # Create a variable that holds the data from the "Sport" column
# sports_column = summer_2016_medals['Sport']
#
# # Find all unique sports and assign to a new variable
# sports = sports_column.unique()
#
# # Print the unique sports
# print(sports)
# Explanation:
# sports_column = summer_2016_medals['Sport']: This extracts the "Sport" column from the DataFrame.
# sports = sports_column.unique(): This finds all unique values in the "Sport" column.
# print(sports): This prints the unique sports to the console.
# This will give you a list of all unique sports present in your dataset.
#
# '''Unique values of a column
# One of the main strengths of Matplotlib is that it can be automated to adapt to the data that it receives as input. For example, if you receive data that has an unknown number of categories, you can still create a bar plot that has bars for each category.
#
# In this exercise and the next, you will be visualizing the weight of athletes in the 2016 summer Olympic Games again, from a dataset that has some unknown number of branches of sports in it. This will be loaded into memory as a pandas DataFrame object called summer_2016_medals, which has a column called "Sport" that tells you to which branch of sport each row corresponds. There is also a "Weight" column that tells you the weight of each athlete.
#
# In this exercise, we will extract the unique values of the "Sport" column
#
# Instructions
# 100 XP
# Create a variable called sports_column that holds the data from the "Sport" column of the DataFrame object.
# Use the unique method of this variable to find all the unique different sports that are present in this data, and assign these values into a new variable called sports.
# Print the sports variable to the console.'''
#
# # Extract the "Sport" column
# sports_column = ____
#
# # Find the unique values of the "Sport" column
# sports = ____
#
# # Print out the unique sports values
# ____
# ChatGPT
# Here’s how you can complete the exercise:
#
# python
# Copy code
# # Extract the "Sport" column
# sports_column = summer_2016_medals['Sport']
#
# # Find the unique values of the "Sport" column
# sports = sports_column.unique()
#
# # Print out the unique sports values
# print(sports)
# Explanation:
# sports_column = summer_2016_medals['Sport']: Extracts the "Sport" column from the summer_2016_medals DataFrame.
# sports = sports_column.unique(): Finds all unique values in the "Sport" column.
# print(sports): Prints the unique sports to the console.

# %%
# incorrect submission
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have loaded your DataFrame 'summer_2016_medals'
# summer_2016_medals = pd.read_csv('your_data_file.csv')

fig, ax = plt.subplots()

# Get unique sports from the "Sport" column
sports = summer_2016_medals['Sport'].unique()

# Loop over the different sports branches
for sport in sports:
    # Extract the rows only for this sport
    sport_df = summer_2016_medals[summer_2016_medals['Sport'] == sport]
    # Calculate mean and standard deviation of "Weight"
    mean_weight = sport_df['Weight'].mean()
    std_weight = sport_df['Weight'].std()
    # Add a bar for the "Weight" mean with std y error bar
    ax.bar(sport, mean_weight, yerr=std_weight, capsize=5, label=sport)

ax.set_ylabel("Weight")
ax.set_xticklabels(sports, rotation=90)

# Save the figure to file
plt.savefig("sports_weights.png")

# Optionally, show the plot
plt.show()

# %%
# correct submission
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have loaded your DataFrame 'summer_2016_medals'
# summer_2016_medals = pd.read_csv('your_data_file.csv')

fig, ax = plt.subplots()

# Get unique sports from the "Sport" column
sports = summer_2016_medals['Sport'].unique()

# Loop over the different sports branches
for sport in sports:
    # Extract the rows only for this sport
    sport_df = summer_2016_medals[summer_2016_medals['Sport'] == sport]
    # Calculate mean and standard deviation of "Weight"
    mean_weight = sport_df['Weight'].mean()
    std_weight = sport_df['Weight'].std()
    # Add a bar for the "Weight" mean with std y error bar
    ax.bar(sport, mean_weight, yerr=std_weight, capsize=5, label=sport)

ax.set_ylabel("Weight")
ax.set_xticklabels(sports, rotation=90)

# Save the figure to file
fig.savefig("sports_weights.png")

# Optionally, show the plot
plt.show()

# %% [markdown]
# That's great! You are now ready to create automated reports from your data.
#
# Don't forget to download the Cheat Sheet for this course to keep track of what you've learned today!
#
#
# Automate your visualization
# One of the main strengths of Matplotlib is that it can be automated to adapt to the data that it receives as input. For example, if you receive data that has an unknown number of categories, you can still create a bar plot that has bars for each category.
# ChatGPT
# Absolutely! Automating visualizations in Matplotlib can help streamline your data analysis process, especially when dealing with dynamic or variable data. Here’s a simple example of how you can automate bar plots to handle an unknown number of categories:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Example data
# data = {
#     'Category': ['A', 'B', 'C', 'D', 'E'],
#     'Values': [23, 45, 56, 78, 33]
# }
#
# df = pd.DataFrame(data)
#
# # Create a bar plot
# def plot_bar(df, category_col, value_col):
#     plt.figure(figsize=(10, 6))
#     plt.bar(df[category_col], df[value_col])
#     plt.xlabel(category_col)
#     plt.ylabel(value_col)
#     plt.title(f'Bar Plot of {value_col} by {category_col}')
#     plt.xticks(rotation=45)
#     plt.tight_layout()
#     plt.show()
#
# # Call the function with column names
# plot_bar(df, 'Category', 'Values')
# In this example:
#
# The plot_bar function automatically creates a bar plot based on the DataFrame df, which could have any number of categories.
# You can adjust the category_col and value_col parameters to match the column names in your dataset.
# If you have an unknown number of categories, this function will still work without needing to manually specify each category. You can also extend this approach to other types of plots, such as line plots or scatter plots, using similar automation techniques.
#
# '''Automate your visualization
# One of the main strengths of Matplotlib is that it can be automated to adapt to the data that it receives as input. For example, if you receive data that has an unknown number of categories, you can still create a bar plot that has bars for each category.
#
# This is what you will do in this exercise. You will be visualizing data about medal winners in the 2016 summer Olympic Games again, but this time you will have a dataset that has some unknown number of branches of sports in it. This will be loaded into memory as a pandas DataFrame object called summer_2016_medals, which has a column called "Sport" that tells you to which branch of sport each row corresponds. There is also a "Weight" column that tells you the weight of each athlete.
#
# Instructions
# 100 XP
# Iterate over the values of sports setting sport as your loop variable.
# In each iteration, extract the rows where the "Sport" column is equal to sport.
# Add a bar to the provided ax object, labeled with the sport name, with the mean of the "Weight" column as its height, and the standard deviation as a y-axis error bar.
# Save the figure into the file "sports_weights.png".'''
#
# fig, ax = plt.subplots()
#
# # Loop over the different sports branches
# for ____ in ____:
#   # Extract the rows only for this sport
#   sport_df = ____
#   # Add a bar for the "Weight" mean with std y error bar
#   ____
#
# ax.set_ylabel("Weight")
# ax.set_xticklabels(sports, rotation=90)
#
# # Save the figure to file
# ____
# ChatGPT
# Here’s how you can complete the code to automate the visualization as per the instructions:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Assuming you have loaded your DataFrame 'summer_2016_medals'
# # summer_2016_medals = pd.read_csv('your_data_file.csv')
#
# fig, ax = plt.subplots()
#
# # Get unique sports from the "Sport" column
# sports = summer_2016_medals['Sport'].unique()
#
# # Loop over the different sports branches
# for sport in sports:
#     # Extract the rows only for this sport
#     sport_df = summer_2016_medals[summer_2016_medals['Sport'] == sport]
#     # Calculate mean and standard deviation of "Weight"
#     mean_weight = sport_df['Weight'].mean()
#     std_weight = sport_df['Weight'].std()
#     # Add a bar for the "Weight" mean with std y error bar
#     ax.bar(sport, mean_weight, yerr=std_weight, capsize=5, label=sport)
#
# ax.set_ylabel("Weight")
# ax.set_xticklabels(sports, rotation=90)
#
# # Save the figure to file
# plt.savefig("sports_weights.png")
#
# # Optionally, show the plot
# plt.show()
# Explanation:
# Loop Over Sports: You get the unique sports from the summer_2016_medals DataFrame and iterate over them.
# Extract Data: For each sport, filter the DataFrame to include only rows corresponding to that sport.
# Calculate Statistics: Compute the mean and standard deviation of the "Weight" column for each sport.
# Plot Bars: Add a bar to the plot with the mean weight and an error bar representing the standard deviation.
# Save Figure: Save the resulting figure as "sports_weights.png".
# Make sure that the summer_2016_medals DataFrame is correctly loaded and contains the necessary columns. Adjust the file path in pd.read_csv or however you load the DataFrame if needed.
#
# Incorrect submission
# Did you call fig.savefig()?
# ChatGPT
# It looks like I missed the correct method for saving the figure. You should use fig.savefig() instead of plt.savefig(). Here's the corrected code:
#
# python
# Copy code
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Assuming you have loaded your DataFrame 'summer_2016_medals'
# # summer_2016_medals = pd.read_csv('your_data_file.csv')
#
# fig, ax = plt.subplots()
#
# # Get unique sports from the "Sport" column
# sports = summer_2016_medals['Sport'].unique()
#
# # Loop over the different sports branches
# for sport in sports:
#     # Extract the rows only for this sport
#     sport_df = summer_2016_medals[summer_2016_medals['Sport'] == sport]
#     # Calculate mean and standard deviation of "Weight"
#     mean_weight = sport_df['Weight'].mean()
#     std_weight = sport_df['Weight'].std()
#     # Add a bar for the "Weight" mean with std y error bar
#     ax.bar(sport, mean_weight, yerr=std_weight, capsize=5, label=sport)
#
# ax.set_ylabel("Weight")
# ax.set_xticklabels(sports, rotation=90)
#
# # Save the figure to file
# fig.savefig("sports_weights.png")
#
# # Optionally, show the plot
# plt.show()
# Explanation of Correction:
# Save Figure: The fig.savefig("sports_weights.png") method is used to save the figure object to a file. This method is preferred over plt.savefig() when you are working with multiple figures or need to specify more details about the file.
# This should ensure your plot is saved correctly.
